# %%
import subprocess
import os
import concurrent.futures

import threading
import sys

def _filter_stderr(pipe):
    noisy_patterns = [
        "MathWorksServiceHost",
        "GLIBCXX_3.4.31",
        "GLIBCXX_3.4.32",
        "CXXABI_1.3.15",
        "libmwflnetwork.so",
        "libmwflcrypto.so",
        "libmwflcryptoutils.so",
        "libmwflcryptoopenssl.so",
        "libmwflurlmgrfactory.so",
    ]

    for line in pipe:
        if not any(p in line for p in noisy_patterns):
            sys.stderr.write(line)
            sys.stderr.flush()

def run(cmd):
    process = subprocess.Popen(
        cmd,
        shell=True,
        text=True,
        stdout=None,              # leave stdout live
        stderr=subprocess.PIPE    # intercept only stderr
    )

    t = threading.Thread(target=_filter_stderr, args=(process.stderr,))
    t.daemon = True
    t.start()

    returncode = process.wait()
    t.join(timeout=1)

    if returncode != 0:
        print(f"Command exited with code {returncode}", file=sys.stderr)

def lastFrame(directory):
    frames = [int(file.split("geo")[1].split(".")[0]) for file in os.listdir(directory) if file.startswith("geo") and file.endswith(".mat")]
    return max(frames)

here = "/home/nickbroussinos/Code/evolving_stokes_2/remesh/"

#Inputs
verbose = 'false'
resume = False
supress_outputs = 0
subdivisions = 18
roughness = .0005
remesh_size = 0;
co = 4 
T = 40000;



param = [0]#CHECK RESUME SETTING!!!




commands = []
for pp in param:
        
       #dt = (1.2e-4)*(pp**(-2.0))
        dt = .01
        #print(dt)
        bb = (pp/.9)*(-4e-8)/(5e-2)
        dir_path = here + f"data/ms_batch_data/pnd_{pp:.2f}"
        start = (lastFrame(dir_path)) if resume else 0
        if resume:
            print(f"start: {start}")
        cmd = f"""export LD_PRELOAD=/usr/lib/x86_64-linux-gnu/libstdc++.so.6 && \
    matlab -nodisplay -nosplash -nodesktop -r "cd '{here}'; verbose = {verbose};\
    supress_outputs = {supress_outputs}; dir = '{dir_path}/'; start = {start};\
    p = struct(); p.roughness = {roughness}; p.dt={dt};p.T={T}; p.start={start}; p.subdivisions={subdivisions};p.beta={bb};p.co={co};p.pnd = {pp};p.remesh_size = {remesh_size};ms_multi; exit" """
        commands.append(cmd)


max_workers = 6
with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(run, cmd) for cmd in commands]
    concurrent.futures.wait(futures)
# Out:
#                             < M A T L A B (R) >
#                   Copyright 1984-2024 The MathWorks, Inc.
#              R2024a Update 3 (24.1.0.2603908) 64-bit (glnxa64)
#                                 May 2, 2024
#
#
# To get started, type doc.
# For product information, visit www.mathworks.com.
#
# Save geo1.mat at j =2, eps_f = 0.01737, eps_d = 0.0001683, eps_v = 4.182, total time: 4.2789
# backtracking failed! reverting to gradient descent
# Save geo2.mat at j =3, eps_f = 0.006053, eps_d = 5.889e-05, eps_v = 4.181, total time: 15.9540
# Save geo3.mat at j =2, eps_f = 0.04521, eps_d = 5.354e-05, eps_v = 4.181, total time: 19.3444
# Save geo4.mat at j =2, eps_f = 0.04503, eps_d = 5.284e-05, eps_v = 4.181, total time: 22.7572
# Save geo5.mat at j =2, eps_f = 0.04451, eps_d = 5.239e-05, eps_v = 4.18, total time: 26.1808
# Save geo6.mat at j =2, eps_f = 0.04399, eps_d = 5.199e-05, eps_v = 4.18, total time: 29.5899
# Save geo7.mat at j =2, eps_f = 0.04345, eps_d = 5.162e-05, eps_v = 4.18, total time: 32.9754
# Save geo8.mat at j =2, eps_f = 0.04289, eps_d = 5.126e-05, eps_v = 4.18, total time: 36.3779
# Save geo9.mat at j =2, eps_f = 0.04233, eps_d = 5.091e-05, eps_v = 4.179, total time: 39.7779
# Save geo10.mat at j =2, eps_f = 0.04176, eps_d = 5.056e-05, eps_v = 4.179, total time: 43.1764
# Save geo11.mat at j =2, eps_f = 0.0412, eps_d = 5.022e-05, eps_v = 4.179, total time: 46.5739
# Remeshed!
# Save geo12.mat at j =2, eps_f = 0.04069, eps_d = 5.057e-05, eps_v = 4.178, total time: 49.9708
# Remeshed!
# Save geo13.mat at j =2, eps_f = 0.04021, eps_d = 4.972e-05, eps_v = 4.178, total time: 53.4075
# Remeshed!
# Save geo14.mat at j =2, eps_f = 0.03983, eps_d = 4.943e-05, eps_v = 4.178, total time: 56.8524
# Remeshed!
# Save geo15.mat at j =2, eps_f = 0.03917, eps_d = 4.921e-05, eps_v = 4.177, total time: 60.3802
# Remeshed!
# Save geo16.mat at j =2, eps_f = 0.03867, eps_d = 4.879e-05, eps_v = 4.177, total time: 63.8962
# Remeshed!
# Save geo17.mat at j =2, eps_f = 0.03832, eps_d = 4.838e-05, eps_v = 4.177, total time: 67.4130
# Remeshed!
# Save geo18.mat at j =2, eps_f = 0.03791, eps_d = 4.816e-05, eps_v = 4.176, total time: 70.8261
# Remeshed!
# Save geo19.mat at j =2, eps_f = 0.03728, eps_d = 4.811e-05, eps_v = 4.176, total time: 74.1796
# Remeshed!
# Save geo20.mat at j =2, eps_f = 0.03676, eps_d = 4.758e-05, eps_v = 4.176, total time: 77.5294
# Remeshed!
# Save geo21.mat at j =2, eps_f = 0.03654, eps_d = 4.737e-05, eps_v = 4.175, total time: 81.0108
# Remeshed!
# Save geo22.mat at j =1, eps_f = 0.04985, eps_d = 8.405e-05, eps_v = 4.178, total time: 83.2087
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo23.mat at j =3, eps_f = 0.009208, eps_d = 5.189e-05, eps_v = 4.177, total time: 95.0000
# Remeshed!
# Save geo24.mat at j =2, eps_f = 0.03841, eps_d = 4.894e-05, eps_v = 4.177, total time: 98.3440
# Remeshed!
# Save geo25.mat at j =2, eps_f = 0.03724, eps_d = 4.82e-05, eps_v = 4.177, total time: 101.7093
# Remeshed!
# Save geo26.mat at j =2, eps_f = 0.03668, eps_d = 4.76e-05, eps_v = 4.176, total time: 105.0393
# Remeshed!
# Save geo27.mat at j =1, eps_f = 0.04999, eps_d = 8.058e-05, eps_v = 4.178, total time: 107.2380
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo28.mat at j =3, eps_f = 0.008953, eps_d = 5.234e-05, eps_v = 4.178, total time: 118.6773
# Remeshed!
# Save geo29.mat at j =2, eps_f = 0.03832, eps_d = 4.899e-05, eps_v = 4.177, total time: 122.0891
# Remeshed!
# Save geo30.mat at j =2, eps_f = 0.03717, eps_d = 4.826e-05, eps_v = 4.177, total time: 125.5111
# Remeshed!
# Save geo31.mat at j =2, eps_f = 0.03626, eps_d = 4.843e-05, eps_v = 4.177, total time: 129.0531
# Remeshed!
# Save geo32.mat at j =2, eps_f = 0.0351, eps_d = 4.813e-05, eps_v = 4.176, total time: 132.8268
# Remeshed!
# Save geo33.mat at j =2, eps_f = 0.03447, eps_d = 4.755e-05, eps_v = 4.176, total time: 136.6087
# Remeshed!
# Save geo34.mat at j =1, eps_f = 0.04986, eps_d = 7.879e-05, eps_v = 4.178, total time: 139.0511
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo35.mat at j =3, eps_f = 0.008285, eps_d = 5.207e-05, eps_v = 4.177, total time: 151.5175
# Remeshed!
# Save geo36.mat at j =2, eps_f = 0.03624, eps_d = 4.881e-05, eps_v = 4.177, total time: 155.1704
# Remeshed!
# Save geo37.mat at j =2, eps_f = 0.0354, eps_d = 4.848e-05, eps_v = 4.177, total time: 159.0573
# Remeshed!
# Save geo38.mat at j =2, eps_f = 0.03469, eps_d = 4.812e-05, eps_v = 4.176, total time: 163.1343
# Remeshed!
# Save geo39.mat at j =2, eps_f = 0.03399, eps_d = 4.763e-05, eps_v = 4.176, total time: 167.2868
# Remeshed!
# Save geo40.mat at j =2, eps_f = 0.03371, eps_d = 4.706e-05, eps_v = 4.176, total time: 171.1994
# Remeshed!
# Save geo41.mat at j =2, eps_f = 0.03358, eps_d = 4.69e-05, eps_v = 4.175, total time: 174.9837
# Remeshed!
# Save geo42.mat at j =1, eps_f = 0.04965, eps_d = 7.955e-05, eps_v = 4.178, total time: 177.5284
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo43.mat at j =3, eps_f = 0.007997, eps_d = 5.15e-05, eps_v = 4.177, total time: 190.4653
# Remeshed!
# Save geo44.mat at j =2, eps_f = 0.03495, eps_d = 4.888e-05, eps_v = 4.176, total time: 194.3414
# Remeshed!
# Save geo45.mat at j =2, eps_f = 0.03407, eps_d = 4.847e-05, eps_v = 4.176, total time: 198.1904
# Remeshed!
# Save geo46.mat at j =2, eps_f = 0.03322, eps_d = 4.809e-05, eps_v = 4.176, total time: 202.2388
# Remeshed!
# Save geo47.mat at j =2, eps_f = 0.03317, eps_d = 4.776e-05, eps_v = 4.175, total time: 206.5792
# Remeshed!
# Save geo48.mat at j =2, eps_f = 0.03309, eps_d = 4.735e-05, eps_v = 4.175, total time: 210.7346
# Remeshed!
# Save geo49.mat at j =2, eps_f = 0.03283, eps_d = 4.746e-05, eps_v = 4.175, total time: 214.7038
# Remeshed!
# Save geo50.mat at j =2, eps_f = 0.03263, eps_d = 4.726e-05, eps_v = 4.174, total time: 218.7349
# Remeshed!
# Save geo51.mat at j =2, eps_f = 0.03231, eps_d = 4.718e-05, eps_v = 4.174, total time: 222.7492
# Remeshed!
# Save geo52.mat at j =2, eps_f = 0.03219, eps_d = 4.703e-05, eps_v = 4.174, total time: 226.8719
# Remeshed!
# Save geo53.mat at j =2, eps_f = 0.03212, eps_d = 4.69e-05, eps_v = 4.173, total time: 231.0355
# Remeshed!
# Save geo54.mat at j =2, eps_f = 0.03229, eps_d = 4.641e-05, eps_v = 4.173, total time: 235.1269
# Remeshed!
# Save geo55.mat at j =1, eps_f = 0.04904, eps_d = 7.974e-05, eps_v = 4.176, total time: 237.8393
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo56.mat at j =3, eps_f = 0.00809, eps_d = 5.056e-05, eps_v = 4.175, total time: 252.3745
# Remeshed!
# Save geo57.mat at j =2, eps_f = 0.03414, eps_d = 4.787e-05, eps_v = 4.175, total time: 256.5488
# Remeshed!
# Save geo58.mat at j =2, eps_f = 0.03335, eps_d = 4.75e-05, eps_v = 4.174, total time: 260.7791
# Remeshed!
# Save geo59.mat at j =2, eps_f = 0.03263, eps_d = 4.721e-05, eps_v = 4.174, total time: 264.8803
# Remeshed!
# Save geo60.mat at j =2, eps_f = 0.03232, eps_d = 4.698e-05, eps_v = 4.174, total time: 269.0362
# Remeshed!
# Save geo61.mat at j =2, eps_f = 0.03193, eps_d = 4.67e-05, eps_v = 4.173, total time: 273.3618
# Remeshed!
# Save geo62.mat at j =2, eps_f = 0.03188, eps_d = 4.713e-05, eps_v = 4.173, total time: 277.7441
# Remeshed!
# Save geo63.mat at j =2, eps_f = 0.03114, eps_d = 4.698e-05, eps_v = 4.173, total time: 282.0050
# Remeshed!
# Save geo64.mat at j =1, eps_f = 0.04967, eps_d = 7.828e-05, eps_v = 4.175, total time: 284.6174
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo65.mat at j =3, eps_f = 0.007793, eps_d = 5.092e-05, eps_v = 4.175, total time: 298.6160
# Remeshed!
# Save geo66.mat at j =2, eps_f = 0.03342, eps_d = 4.804e-05, eps_v = 4.174, total time: 302.7768
# Remeshed!
# Save geo67.mat at j =2, eps_f = 0.03277, eps_d = 4.727e-05, eps_v = 4.174, total time: 306.9364
# Remeshed!
# Save geo68.mat at j =2, eps_f = 0.0326, eps_d = 4.688e-05, eps_v = 4.174, total time: 311.0716
# Remeshed!
# Save geo69.mat at j =2, eps_f = 0.03234, eps_d = 4.691e-05, eps_v = 4.173, total time: 315.2292
# Remeshed!
# Save geo70.mat at j =2, eps_f = 0.03214, eps_d = 4.664e-05, eps_v = 4.173, total time: 319.3354
# Remeshed!
# Save geo71.mat at j =2, eps_f = 0.03152, eps_d = 4.713e-05, eps_v = 4.173, total time: 323.4468
# Remeshed!
# Save geo72.mat at j =2, eps_f = 0.03093, eps_d = 4.68e-05, eps_v = 4.172, total time: 327.5988
# Remeshed!
# Save geo73.mat at j =2, eps_f = 0.03097, eps_d = 4.639e-05, eps_v = 4.172, total time: 331.7737
# Remeshed!
# Save geo74.mat at j =2, eps_f = 0.03098, eps_d = 4.633e-05, eps_v = 4.172, total time: 335.9823
# Remeshed!
# Save geo75.mat at j =2, eps_f = 0.03067, eps_d = 4.627e-05, eps_v = 4.172, total time: 340.0514
# Remeshed!
# Save geo76.mat at j =2, eps_f = 0.03056, eps_d = 4.647e-05, eps_v = 4.171, total time: 344.2088
# Remeshed!
# Save geo77.mat at j =2, eps_f = 0.0302, eps_d = 4.692e-05, eps_v = 4.171, total time: 348.3302
# Remeshed!
# Save geo78.mat at j =2, eps_f = 0.02996, eps_d = 4.678e-05, eps_v = 4.171, total time: 352.4948
# Remeshed!
# Save geo79.mat at j =2, eps_f = 0.03019, eps_d = 4.691e-05, eps_v = 4.171, total time: 356.6241
# Remeshed!
# Save geo80.mat at j =2, eps_f = 0.03013, eps_d = 4.612e-05, eps_v = 4.17, total time: 360.7806
# Remeshed!
# Save geo81.mat at j =1, eps_f = 0.04929, eps_d = 7.879e-05, eps_v = 4.174, total time: 363.3233
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo82.mat at j =3, eps_f = 0.007557, eps_d = 4.978e-05, eps_v = 4.173, total time: 377.4223
# Remeshed!
# Save geo83.mat at j =2, eps_f = 0.03213, eps_d = 4.707e-05, eps_v = 4.173, total time: 381.6273
# Remeshed!
# Save geo84.mat at j =1, eps_f = 0.04967, eps_d = 7.59e-05, eps_v = 4.176, total time: 384.3235
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo85.mat at j =3, eps_f = 0.007666, eps_d = 5.169e-05, eps_v = 4.175, total time: 398.9598
# Remeshed!
# Save geo86.mat at j =2, eps_f = 0.03375, eps_d = 4.798e-05, eps_v = 4.174, total time: 403.5168
# Remeshed!
# Save geo87.mat at j =2, eps_f = 0.03306, eps_d = 4.767e-05, eps_v = 4.174, total time: 408.0592
# Remeshed!
# Save geo88.mat at j =2, eps_f = 0.03266, eps_d = 4.728e-05, eps_v = 4.174, total time: 412.6630
# Remeshed!
# Save geo89.mat at j =2, eps_f = 0.03199, eps_d = 4.797e-05, eps_v = 4.174, total time: 417.0940
# Remeshed!
# Save geo90.mat at j =2, eps_f = 0.03114, eps_d = 4.743e-05, eps_v = 4.173, total time: 421.6833
# Remeshed!
# Save geo91.mat at j =2, eps_f = 0.03143, eps_d = 4.73e-05, eps_v = 4.173, total time: 426.1743
# Remeshed!
# Save geo92.mat at j =1, eps_f = 0.04934, eps_d = 7.744e-05, eps_v = 4.176, total time: 429.1046
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo93.mat at j =3, eps_f = 0.007794, eps_d = 5.062e-05, eps_v = 4.175, total time: 444.4468
# Remeshed!
# Save geo94.mat at j =2, eps_f = 0.0336, eps_d = 4.811e-05, eps_v = 4.175, total time: 448.6456
# Remeshed!
# Save geo95.mat at j =2, eps_f = 0.03283, eps_d = 4.795e-05, eps_v = 4.174, total time: 452.7979
# Remeshed!
# Save geo96.mat at j =2, eps_f = 0.03233, eps_d = 4.752e-05, eps_v = 4.174, total time: 456.9012
# Remeshed!
# Save geo97.mat at j =2, eps_f = 0.03183, eps_d = 4.797e-05, eps_v = 4.174, total time: 461.0669
# Remeshed!
# Save geo98.mat at j =2, eps_f = 0.03155, eps_d = 4.773e-05, eps_v = 4.173, total time: 465.1372
# Remeshed!
# Save geo99.mat at j =1, eps_f = 0.04968, eps_d = 7.704e-05, eps_v = 4.176, total time: 467.7372
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo100.mat at j =3, eps_f = 0.007675, eps_d = 5.099e-05, eps_v = 4.175, total time: 482.0962
# Remeshed!
# Save geo101.mat at j =2, eps_f = 0.03347, eps_d = 4.845e-05, eps_v = 4.175, total time: 486.1858
# Remeshed!
# Save geo102.mat at j =2, eps_f = 0.03317, eps_d = 4.762e-05, eps_v = 4.175, total time: 490.5132
# Remeshed!
# Save geo103.mat at j =2, eps_f = 0.03311, eps_d = 4.794e-05, eps_v = 4.174, total time: 494.6583
# Remeshed!
# Save geo104.mat at j =2, eps_f = 0.03237, eps_d = 4.785e-05, eps_v = 4.174, total time: 498.8559
# Remeshed!
# Save geo105.mat at j =2, eps_f = 0.03205, eps_d = 4.786e-05, eps_v = 4.174, total time: 503.0396
# Remeshed!
# Save geo106.mat at j =2, eps_f = 0.0316, eps_d = 4.751e-05, eps_v = 4.173, total time: 507.2910
# Remeshed!
# Save geo107.mat at j =2, eps_f = 0.03173, eps_d = 4.789e-05, eps_v = 4.173, total time: 511.5825
# Remeshed!
# Save geo108.mat at j =2, eps_f = 0.03087, eps_d = 4.754e-05, eps_v = 4.173, total time: 515.8597
# Remeshed!
# Save geo109.mat at j =2, eps_f = 0.03098, eps_d = 4.756e-05, eps_v = 4.173, total time: 520.0556
# Remeshed!
# Save geo110.mat at j =1, eps_f = 0.04938, eps_d = 7.953e-05, eps_v = 4.176, total time: 522.7636
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo111.mat at j =3, eps_f = 0.007858, eps_d = 5.085e-05, eps_v = 4.175, total time: 537.6838
# Remeshed!
# Save geo112.mat at j =2, eps_f = 0.03321, eps_d = 4.844e-05, eps_v = 4.174, total time: 541.9979
# Remeshed!
# Save geo113.mat at j =2, eps_f = 0.03307, eps_d = 4.755e-05, eps_v = 4.174, total time: 546.1353
# Remeshed!
# Save geo114.mat at j =1, eps_f = 0.04966, eps_d = 7.813e-05, eps_v = 4.177, total time: 548.8426
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo115.mat at j =3, eps_f = 0.007963, eps_d = 5.177e-05, eps_v = 4.176, total time: 563.4481
# Remeshed!
# Save geo116.mat at j =2, eps_f = 0.03486, eps_d = 4.905e-05, eps_v = 4.176, total time: 567.8009
# Remeshed!
# Save geo117.mat at j =2, eps_f = 0.03381, eps_d = 4.929e-05, eps_v = 4.175, total time: 572.0979
# Remeshed!
# Save geo118.mat at j =2, eps_f = 0.03285, eps_d = 4.848e-05, eps_v = 4.175, total time: 576.2700
# Remeshed!
# Save geo119.mat at j =2, eps_f = 0.0327, eps_d = 4.828e-05, eps_v = 4.175, total time: 580.5376
# Remeshed!
# Save geo120.mat at j =2, eps_f = 0.03205, eps_d = 4.783e-05, eps_v = 4.174, total time: 584.7495
# Remeshed!
# Save geo121.mat at j =2, eps_f = 0.03208, eps_d = 4.759e-05, eps_v = 4.174, total time: 588.9863
# Remeshed!
# Save geo122.mat at j =2, eps_f = 0.03226, eps_d = 4.779e-05, eps_v = 4.174, total time: 593.3363
# Remeshed!
# Save geo123.mat at j =1, eps_f = 0.04993, eps_d = 7.888e-05, eps_v = 4.177, total time: 596.0630
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo124.mat at j =3, eps_f = 0.007864, eps_d = 5.119e-05, eps_v = 4.176, total time: 610.8093
# Remeshed!
# Save geo125.mat at j =2, eps_f = 0.03409, eps_d = 4.955e-05, eps_v = 4.175, total time: 615.0241
# Remeshed!
# Save geo126.mat at j =2, eps_f = 0.03311, eps_d = 4.835e-05, eps_v = 4.175, total time: 619.2032
# Remeshed!
# Save geo127.mat at j =2, eps_f = 0.03304, eps_d = 4.814e-05, eps_v = 4.175, total time: 623.4193
# Remeshed!
# Save geo128.mat at j =2, eps_f = 0.0328, eps_d = 4.837e-05, eps_v = 4.174, total time: 627.5630
# Remeshed!
# Save geo129.mat at j =2, eps_f = 0.03223, eps_d = 4.75e-05, eps_v = 4.174, total time: 631.6252
# Remeshed!
# Save geo130.mat at j =1, eps_f = 0.04972, eps_d = 7.972e-05, eps_v = 4.177, total time: 634.2937
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo131.mat at j =3, eps_f = 0.007957, eps_d = 5.176e-05, eps_v = 4.176, total time: 648.9209
# Remeshed!
# Save geo132.mat at j =2, eps_f = 0.03457, eps_d = 4.888e-05, eps_v = 4.176, total time: 653.3413
# Remeshed!
# Save geo133.mat at j =2, eps_f = 0.03374, eps_d = 4.865e-05, eps_v = 4.175, total time: 657.6767
# Remeshed!
# Save geo134.mat at j =2, eps_f = 0.03335, eps_d = 4.834e-05, eps_v = 4.175, total time: 662.0108
# Remeshed!
# Save geo135.mat at j =2, eps_f = 0.03333, eps_d = 4.824e-05, eps_v = 4.175, total time: 666.2138
# Remeshed!
# Save geo136.mat at j =1, eps_f = 0.04999, eps_d = 7.858e-05, eps_v = 4.177, total time: 668.9255
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo137.mat at j =3, eps_f = 0.007949, eps_d = 5.219e-05, eps_v = 4.176, total time: 683.5546
# Remeshed!
# Save geo138.mat at j =2, eps_f = 0.03434, eps_d = 4.935e-05, eps_v = 4.176, total time: 687.8200
# Remeshed!
# Save geo139.mat at j =2, eps_f = 0.03412, eps_d = 4.879e-05, eps_v = 4.176, total time: 692.0823
# Remeshed!
# Save geo140.mat at j =2, eps_f = 0.03368, eps_d = 4.893e-05, eps_v = 4.175, total time: 696.2904
# Remeshed!
# Save geo141.mat at j =2, eps_f = 0.03286, eps_d = 4.86e-05, eps_v = 4.175, total time: 700.5333
# Remeshed!
# Save geo142.mat at j =2, eps_f = 0.03228, eps_d = 4.888e-05, eps_v = 4.175, total time: 704.7811
# Remeshed!
# Save geo143.mat at j =2, eps_f = 0.03193, eps_d = 4.848e-05, eps_v = 4.175, total time: 708.9376
# Remeshed!
# Save geo144.mat at j =2, eps_f = 0.03176, eps_d = 4.793e-05, eps_v = 4.174, total time: 713.1831
# Remeshed!
# Save geo145.mat at j =1, eps_f = 0.0498, eps_d = 8.046e-05, eps_v = 4.177, total time: 715.9195
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo146.mat at j =3, eps_f = 0.007852, eps_d = 5.246e-05, eps_v = 4.176, total time: 730.5010
# Remeshed!
# Save geo147.mat at j =2, eps_f = 0.03354, eps_d = 4.986e-05, eps_v = 4.176, total time: 734.7529
# Remeshed!
# Save geo148.mat at j =2, eps_f = 0.03293, eps_d = 4.868e-05, eps_v = 4.175, total time: 739.0239
# Remeshed!
# Save geo149.mat at j =2, eps_f = 0.03294, eps_d = 4.816e-05, eps_v = 4.175, total time: 743.3429
# Remeshed!
# Save geo150.mat at j =2, eps_f = 0.03261, eps_d = 4.827e-05, eps_v = 4.175, total time: 747.6721
# Remeshed!
# Save geo151.mat at j =2, eps_f = 0.03178, eps_d = 4.828e-05, eps_v = 4.174, total time: 751.9155
# Remeshed!
# Save geo152.mat at j =2, eps_f = 0.03144, eps_d = 4.809e-05, eps_v = 4.174, total time: 756.2296
# Remeshed!
# Save geo153.mat at j =2, eps_f = 0.03154, eps_d = 4.762e-05, eps_v = 4.174, total time: 760.4723
# Remeshed!
# Save geo154.mat at j =1, eps_f = 0.0498, eps_d = 7.985e-05, eps_v = 4.176, total time: 763.2314
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo155.mat at j =3, eps_f = 0.007689, eps_d = 5.127e-05, eps_v = 4.176, total time: 777.7759
# Remeshed!
# Save geo156.mat at j =2, eps_f = 0.03342, eps_d = 4.856e-05, eps_v = 4.175, total time: 782.0633
# Remeshed!
# Save geo157.mat at j =1, eps_f = 0.04946, eps_d = 7.751e-05, eps_v = 4.178, total time: 784.7459
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo158.mat at j =3, eps_f = 0.007859, eps_d = 5.265e-05, eps_v = 4.177, total time: 799.5945
# Remeshed!
# Save geo159.mat at j =2, eps_f = 0.03502, eps_d = 5.018e-05, eps_v = 4.177, total time: 803.9065
# Remeshed!
# Save geo160.mat at j =2, eps_f = 0.03355, eps_d = 4.926e-05, eps_v = 4.176, total time: 808.1818
# Remeshed!
# Save geo161.mat at j =2, eps_f = 0.03314, eps_d = 4.89e-05, eps_v = 4.176, total time: 812.5260
# Remeshed!
# Save geo162.mat at j =2, eps_f = 0.03257, eps_d = 4.87e-05, eps_v = 4.176, total time: 816.8923
# Remeshed!
# Save geo163.mat at j =2, eps_f = 0.03254, eps_d = 4.827e-05, eps_v = 4.175, total time: 821.2590
# Remeshed!
# Save geo164.mat at j =2, eps_f = 0.03249, eps_d = 4.84e-05, eps_v = 4.175, total time: 825.7512
# Remeshed!
# Save geo165.mat at j =2, eps_f = 0.03187, eps_d = 4.864e-05, eps_v = 4.175, total time: 830.1926
# Remeshed!
# Save geo166.mat at j =2, eps_f = 0.03145, eps_d = 4.836e-05, eps_v = 4.174, total time: 834.6151
# Remeshed!
# Save geo167.mat at j =1, eps_f = 0.04978, eps_d = 7.997e-05, eps_v = 4.177, total time: 837.4332
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo168.mat at j =3, eps_f = 0.007574, eps_d = 5.17e-05, eps_v = 4.176, total time: 852.5941
# Remeshed!
# Save geo169.mat at j =2, eps_f = 0.03355, eps_d = 4.931e-05, eps_v = 4.176, total time: 856.9684
# Remeshed!
# Save geo170.mat at j =2, eps_f = 0.03279, eps_d = 4.873e-05, eps_v = 4.175, total time: 861.4057
# Remeshed!
# Save geo171.mat at j =2, eps_f = 0.03206, eps_d = 4.882e-05, eps_v = 4.175, total time: 865.8202
# Remeshed!
# Save geo172.mat at j =2, eps_f = 0.03169, eps_d = 4.81e-05, eps_v = 4.175, total time: 870.0805
# Remeshed!
# Save geo173.mat at j =2, eps_f = 0.03175, eps_d = 4.813e-05, eps_v = 4.174, total time: 874.4162
# Remeshed!
# Save geo174.mat at j =1, eps_f = 0.04942, eps_d = 7.912e-05, eps_v = 4.177, total time: 877.1581
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo175.mat at j =3, eps_f = 0.00761, eps_d = 5.168e-05, eps_v = 4.176, total time: 891.8757
# Remeshed!
# Save geo176.mat at j =2, eps_f = 0.03374, eps_d = 4.894e-05, eps_v = 4.176, total time: 896.1612
# Remeshed!
# Save geo177.mat at j =2, eps_f = 0.03303, eps_d = 4.817e-05, eps_v = 4.175, total time: 900.4475
# Remeshed!
# Save geo178.mat at j =1, eps_f = 0.04963, eps_d = 7.77e-05, eps_v = 4.178, total time: 903.1928
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo179.mat at j =3, eps_f = 0.007626, eps_d = 5.282e-05, eps_v = 4.177, total time: 918.2375
# Remeshed!
# Save geo180.mat at j =2, eps_f = 0.0341, eps_d = 4.955e-05, eps_v = 4.176, total time: 922.6706
# Remeshed!
# Save geo181.mat at j =2, eps_f = 0.03348, eps_d = 4.862e-05, eps_v = 4.176, total time: 927.0591
# Remeshed!
# Save geo182.mat at j =2, eps_f = 0.03287, eps_d = 4.864e-05, eps_v = 4.176, total time: 931.3746
# Remeshed!
# Save geo183.mat at j =1, eps_f = 0.04983, eps_d = 7.803e-05, eps_v = 4.178, total time: 934.1141
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo184.mat at j =3, eps_f = 0.007711, eps_d = 5.237e-05, eps_v = 4.177, total time: 948.9896
# Remeshed!
# Save geo185.mat at j =2, eps_f = 0.03449, eps_d = 4.998e-05, eps_v = 4.177, total time: 953.3343
# Remeshed!
# Save geo186.mat at j =2, eps_f = 0.03326, eps_d = 4.891e-05, eps_v = 4.176, total time: 957.6718
# Remeshed!
# Save geo187.mat at j =2, eps_f = 0.03316, eps_d = 4.868e-05, eps_v = 4.176, total time: 962.0635
# Remeshed!
# Save geo188.mat at j =2, eps_f = 0.03263, eps_d = 4.867e-05, eps_v = 4.176, total time: 966.3387
# Remeshed!
# Save geo189.mat at j =2, eps_f = 0.03198, eps_d = 4.839e-05, eps_v = 4.175, total time: 970.7141
# Remeshed!
# Save geo190.mat at j =2, eps_f = 0.03211, eps_d = 4.847e-05, eps_v = 4.175, total time: 975.0367
# Remeshed!
# Save geo191.mat at j =1, eps_f = 0.04997, eps_d = 7.752e-05, eps_v = 4.177, total time: 977.8359
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo192.mat at j =3, eps_f = 0.007575, eps_d = 5.204e-05, eps_v = 4.177, total time: 992.6844
# Remeshed!
# Save geo193.mat at j =2, eps_f = 0.03363, eps_d = 4.955e-05, eps_v = 4.176, total time: 997.0404
# Remeshed!
# Save geo194.mat at j =2, eps_f = 0.03293, eps_d = 4.939e-05, eps_v = 4.176, total time: 1001.3629
# Remeshed!
# Save geo195.mat at j =2, eps_f = 0.03233, eps_d = 4.812e-05, eps_v = 4.176, total time: 1005.6775
# Remeshed!
# Save geo196.mat at j =2, eps_f = 0.03223, eps_d = 4.877e-05, eps_v = 4.175, total time: 1010.0005
# Remeshed!
# Save geo197.mat at j =2, eps_f = 0.03173, eps_d = 4.829e-05, eps_v = 4.175, total time: 1014.2411
# Remeshed!
# Save geo198.mat at j =2, eps_f = 0.03156, eps_d = 4.829e-05, eps_v = 4.174, total time: 1018.5463
# Remeshed!
# Save geo199.mat at j =2, eps_f = 0.0312, eps_d = 4.817e-05, eps_v = 4.174, total time: 1022.8957
# Remeshed!
# Save geo200.mat at j =2, eps_f = 0.03094, eps_d = 4.805e-05, eps_v = 4.174, total time: 1027.2455
# Remeshed!
# Save geo201.mat at j =2, eps_f = 0.03072, eps_d = 4.784e-05, eps_v = 4.174, total time: 1031.6032
# Remeshed!
# Save geo202.mat at j =2, eps_f = 0.03029, eps_d = 4.797e-05, eps_v = 4.173, total time: 1036.0059
# Remeshed!
# Save geo203.mat at j =2, eps_f = 0.02999, eps_d = 4.766e-05, eps_v = 4.173, total time: 1040.4548
# Remeshed!
# Save geo204.mat at j =2, eps_f = 0.03007, eps_d = 4.747e-05, eps_v = 4.173, total time: 1044.8459
# Remeshed!
# Save geo205.mat at j =1, eps_f = 0.04995, eps_d = 7.689e-05, eps_v = 4.175, total time: 1047.6197
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo206.mat at j =3, eps_f = 0.007271, eps_d = 5.082e-05, eps_v = 4.174, total time: 1062.6926
# Remeshed!
# Save geo207.mat at j =2, eps_f = 0.03206, eps_d = 4.812e-05, eps_v = 4.174, total time: 1067.0302
# Remeshed!
# Save geo208.mat at j =1, eps_f = 0.04946, eps_d = 7.436e-05, eps_v = 4.177, total time: 1069.7956
# Remeshed!
# backtracking failed! reverting to gradient descent
# Save geo209.mat at j =3, eps_f = 0.007332, eps_d = 5.267e-05, eps_v = 4.176, total time: 1084.9604
# Remeshed!
# Save geo210.mat at j =2, eps_f = 0.03303, eps_d = 4.917e-05, eps_v = 4.176, total time: 1089.3515
# Remeshed!
# Save geo211.mat at j =2, eps_f = 0.03267, eps_d = 4.828e-05, eps_v = 4.175, total time: 1093.7352
# Remeshed!
# Save geo212.mat at j =2, eps_f = 0.032, eps_d = 4.833e-05, eps_v = 4.175, total time: 1098.4996
# Remeshed!
# Save geo213.mat at j =2, eps_f = 0.03128, eps_d = 4.854e-05, eps_v = 4.174, total time: 1102.9923
# Remeshed!
# Save geo214.mat at j =2, eps_f = 0.03068, eps_d = 4.84e-05, eps_v = 4.174, total time: 1107.4930
# Remeshed!
# Operation terminated by user during stokeslet_SLP (line 44)
#
#
# In ms_multi (line 161)
#         slpout = stokeslet_SLP(P,geo.v_area,f_mem); u_back = shearextensionflow(P,gamy);
#
# Operation terminated by user during stokeslet_SLP (line 44)
#
#
# In ms_multi (line 161)
#         slpout = stokeslet_SLP(P,geo.v_area,f_mem); u_back = shearextensionflow(P,gamy);
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 89
#      88 futures = [executor.submit(run, cmd) for cmd in commands]
# ---> 89 concurrent.futures.wait(futures)
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:307, in wait(fs, timeout, return_when)
#     305     waiter = _create_and_install_waiters(fs, return_when)
# --> 307 waiter.event.wait(timeout)
#     308 for f in fs:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 87
#      83         commands.append(cmd)
#      86 max_workers = 6
# ---> 87 with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
#      88     futures = [executor.submit(run, cmd) for cmd in commands]
#      89     concurrent.futures.wait(futures)
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# Command exited with code -2
