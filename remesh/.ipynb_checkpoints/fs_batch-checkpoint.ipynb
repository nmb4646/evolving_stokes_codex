# %%
import subprocess
import os
import concurrent.futures

import threading
import sys

def _filter_stderr(pipe):
    noisy_patterns = [
        "MathWorksServiceHost",
        "GLIBCXX_3.4.31",
        "GLIBCXX_3.4.32",
        "CXXABI_1.3.15",
        "libmwflnetwork.so",
        "libmwflcrypto.so",
        "libmwflcryptoutils.so",
        "libmwflcryptoopenssl.so",
        "libmwflurlmgrfactory.so",
    ]

    for line in pipe:
        if not any(p in line for p in noisy_patterns):
            sys.stderr.write(line)
            sys.stderr.flush()

def run(cmd):
    process = subprocess.Popen(
        cmd,
        shell=True,
        text=True,
        stdout=None,
        stderr=subprocess.PIPE
    )

    t = threading.Thread(target=_filter_stderr, args=(process.stderr,))
    t.daemon = True
    t.start()

    returncode = process.wait()
    t.join(timeout=1)

    if returncode != 0:
        print(f"Command exited with code {returncode}", file=sys.stderr)

def lastFrame(directory):
    frames = [int(file.split("geo")[1].split(".")[0]) for file in os.listdir(directory) if file.startswith("geo") and file.endswith(".mat")]
    return max(frames)

here = "/home/nickbroussinos/Code/evolving_stokes_codex/remesh/"

# Inputs
verbose = 'true'
resume = False
supress_outputs = 0
subdivisions = 8
roughness = .0005
remesh_size = 0
T = 40000
k = 100000
Da = 100
Sd = 100
Gamma = 0
gamy = 4
chi = 1

param = [.005] # dt values

### ALWAYS CHECK RESUME VALUE ###

commands = []
for dt in param:
        run_tag = f"Sd_{Sd:.2e}_Da_{Da:.2e}_gamy_{gamy:+.2e}".replace('+', 'p').replace('-', 'm')
        dir_path = here + f"data/fs_batch_data/{run_tag}"
        os.makedirs(dir_path, exist_ok=True)
        start = (lastFrame(dir_path)) if resume else 0
        if resume:
            print(f"start: {start}")
        cmd = f"""export LD_PRELOAD=/usr/lib/x86_64-linux-gnu/libstdc++.so.6 && \
    matlab -nodisplay -nosplash -nodesktop -r "cd '{here}'; verbose = {verbose};\
    supress_outputs = {supress_outputs}; dir = '{dir_path}/'; start = {start};\
    p = struct(); p.roughness = {roughness}; p.dt={dt}; p.T={T}; p.start={start};\
    p.subdivisions={subdivisions}; p.k={k}; p.remesh_size = {remesh_size};\
    p.Da={Da}; p.Sd={Sd}; p.Gamma={Gamma}; p.gamy={gamy}; p.chi={chi}; fs_multi; exit" """
        commands.append(cmd)


max_workers = 6
with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(run, cmd) for cmd in commands]
    concurrent.futures.wait(futures)
# Out:
#                             < M A T L A B (R) >
#                   Copyright 1984-2024 The MathWorks, Inc.
#              R2024a Update 3 (24.1.0.2603908) 64-bit (glnxa64)
#                                 May 2, 2024
#
#
# To get started, type doc.
# For product information, visit www.mathworks.com.
#
# Save geo0.mat
# t = 1, j = 0, ls_iter = 1, eps_b = 0.2835, eps_c = 1.517e-08, eps_d = 1.876e-05, darea = 0.0002347
# t = 1, j = 1, ls_iter = 1, eps_b = 0.03092, eps_c = 1.379e-09, eps_d = 1.882e-05, darea = 0.0002354
# t = 1, j = 2, ls_iter = 1, eps_b = 0.005639, eps_c = 1.266e-09, eps_d = 1.886e-05, darea = 0.0002358
# Save geo1.mat at j = 3, eps_b = 0.005639, eps_c = 1.266e-09, eps_d = 1.886e-05, total time: 3.4810
# t = 2, j = 0, ls_iter = 1, eps_b = 1.354, eps_c = 3.716e-08, eps_d = 2.729e-07, darea = 3.413e-06
# t = 2, j = 1, ls_iter = 1, eps_b = 0.1194, eps_c = 5.332e-09, eps_d = 2.156e-07, darea = 2.696e-06
# t = 2, j = 2, ls_iter = 1, eps_b = 0.02038, eps_c = 5.323e-09, eps_d = 2.09e-07, darea = 2.614e-06
# t = 2, j = 3, ls_iter = 1, eps_b = 0.003935, eps_c = 5.9e-09, eps_d = 2.081e-07, darea = 2.602e-06
# Save geo2.mat at j = 4, eps_b = 0.003935, eps_c = 5.9e-09, eps_d = 2.081e-07, total time: 7.3537
# t = 3, j = 0, ls_iter = 1, eps_b = 0.5602, eps_c = 1.315e-08, eps_d = 4.006e-08, darea = 5.01e-07
# t = 3, j = 1, ls_iter = 1, eps_b = 0.09368, eps_c = 9.611e-09, eps_d = 3.251e-08, darea = 4.066e-07
# t = 3, j = 2, ls_iter = 1, eps_b = 0.01741, eps_c = 1.038e-08, eps_d = 3.144e-08, darea = 3.932e-07
# t = 3, j = 3, ls_iter = 1, eps_b = 0.00342, eps_c = 1.137e-08, eps_d = 3.126e-08, darea = 3.91e-07
# Save geo3.mat at j = 4, eps_b = 0.00342, eps_c = 1.137e-08, eps_d = 3.126e-08, total time: 11.1254
# t = 4, j = 0, ls_iter = 1, eps_b = 0.3313, eps_c = 1.654e-08, eps_d = 1.065e-08, darea = 1.331e-07
# t = 4, j = 1, ls_iter = 1, eps_b = 0.06067, eps_c = 1.768e-08, eps_d = 9.08e-09, darea = 1.136e-07
# t = 4, j = 2, ls_iter = 1, eps_b = 0.0114, eps_c = 1.614e-08, eps_d = 8.853e-09, darea = 1.107e-07
# t = 4, j = 3, ls_iter = 1, eps_b = 0.00225, eps_c = 1.737e-08, eps_d = 8.816e-09, darea = 1.103e-07
# Save geo4.mat at j = 4, eps_b = 0.00225, eps_c = 1.737e-08, eps_d = 8.816e-09, total time: 14.9071
# t = 5, j = 0, ls_iter = 1, eps_b = 0.1984, eps_c = 2.291e-08, eps_d = 3.676e-09, darea = 4.597e-08
# t = 5, j = 1, ls_iter = 1, eps_b = 0.03618, eps_c = 2.453e-08, eps_d = 3.268e-09, darea = 4.088e-08
# t = 5, j = 2, ls_iter = 1, eps_b = 0.006769, eps_c = 2.182e-08, eps_d = 3.212e-09, darea = 4.017e-08
# Save geo5.mat at j = 3, eps_b = 0.006769, eps_c = 2.182e-08, eps_d = 3.212e-09, total time: 18.0427
# t = 6, j = 0, ls_iter = 1, eps_b = 0.1174, eps_c = 2.782e-08, eps_d = 1.497e-09, darea = 1.872e-08
# t = 6, j = 1, ls_iter = 1, eps_b = 0.02091, eps_c = 2.922e-08, eps_d = 1.37e-09, darea = 1.714e-08
# t = 6, j = 2, ls_iter = 1, eps_b = 0.003878, eps_c = 2.71e-08, eps_d = 1.354e-09, darea = 1.694e-08
# Save geo6.mat at j = 3, eps_b = 0.003878, eps_c = 2.71e-08, eps_d = 1.354e-09, total time: 21.1399
# t = 7, j = 0, ls_iter = 1, eps_b = 0.06727, eps_c = 3.21e-08, eps_d = 6.718e-10, darea = 8.402e-09
# t = 7, j = 1, ls_iter = 1, eps_b = 0.0115, eps_c = 3.433e-08, eps_d = 6.265e-10, darea = 7.835e-09
# t = 7, j = 2, ls_iter = 1, eps_b = 0.002093, eps_c = 3.292e-08, eps_d = 6.214e-10, darea = 7.772e-09
# Save geo7.mat at j = 3, eps_b = 0.002093, eps_c = 3.292e-08, eps_d = 6.214e-10, total time: 24.2417
# t = 8, j = 0, ls_iter = 1, eps_b = 0.03908, eps_c = 3.661e-08, eps_d = 3.092e-10, darea = 3.867e-09
# t = 8, j = 1, ls_iter = 1, eps_b = 0.006335, eps_c = 3.712e-08, eps_d = 2.908e-10, darea = 3.637e-09
# Save geo8.mat at j = 2, eps_b = 0.006335, eps_c = 3.712e-08, eps_d = 2.908e-10, total time: 26.6952
# t = 9, j = 0, ls_iter = 1, eps_b = 0.02476, eps_c = 3.873e-08, eps_d = 1.293e-10, darea = 1.617e-09
# t = 9, j = 1, ls_iter = 1, eps_b = 0.003835, eps_c = 3.983e-08, eps_d = 1.209e-10, darea = 1.512e-09
# Save geo9.mat at j = 2, eps_b = 0.003835, eps_c = 3.983e-08, eps_d = 1.209e-10, total time: 29.1786
# t = 10, j = 0, ls_iter = 1, eps_b = 0.01519, eps_c = 3.929e-08, eps_d = 3.154e-11, darea = 3.944e-10
# t = 10, j = 1, ls_iter = 1, eps_b = 0.002221, eps_c = 4.662e-08, eps_d = 2.755e-11, darea = 3.446e-10
# Save geo10.mat at j = 2, eps_b = 0.002221, eps_c = 4.662e-08, eps_d = 2.755e-11, total time: 31.6095
# t = 11, j = 0, ls_iter = 1, eps_b = 0.009746, eps_c = 4.431e-08, eps_d = 2.541e-11, darea = -3.178e-10
# Save geo11.mat at j = 1, eps_b = 0.009746, eps_c = 4.431e-08, eps_d = 2.541e-11, total time: 33.3786
# t = 12, j = 0, ls_iter = 1, eps_b = 0.008114, eps_c = 4.691e-08, eps_d = 6.111e-11, darea = -7.642e-10
# Save geo12.mat at j = 1, eps_b = 0.008114, eps_c = 4.691e-08, eps_d = 6.111e-11, total time: 35.2097
# t = 13, j = 0, ls_iter = 1, eps_b = 0.005716, eps_c = 4.967e-08, eps_d = 8.419e-11, darea = -1.053e-09
# Save geo13.mat at j = 1, eps_b = 0.005716, eps_c = 4.967e-08, eps_d = 8.419e-11, total time: 36.9842
# t = 14, j = 0, ls_iter = 1, eps_b = 0.004033, eps_c = 4.791e-08, eps_d = 9.944e-11, darea = -1.244e-09
# Save geo14.mat at j = 1, eps_b = 0.004033, eps_c = 4.791e-08, eps_d = 9.944e-11, total time: 38.7582
# t = 15, j = 0, ls_iter = 1, eps_b = 0.002976, eps_c = 4.821e-08, eps_d = 1.097e-10, darea = -1.372e-09
# Save geo15.mat at j = 1, eps_b = 0.002976, eps_c = 4.821e-08, eps_d = 1.097e-10, total time: 40.5461
# t = 16, j = 0, ls_iter = 1, eps_b = 0.002296, eps_c = 4.923e-08, eps_d = 1.168e-10, darea = -1.46e-09
# Save geo16.mat at j = 1, eps_b = 0.002296, eps_c = 4.923e-08, eps_d = 1.168e-10, total time: 42.3168
# t = 17, j = 0, ls_iter = 1, eps_b = 0.001828, eps_c = 5.369e-08, eps_d = 1.216e-10, darea = -1.521e-09
# Save geo17.mat at j = 1, eps_b = 0.001828, eps_c = 5.369e-08, eps_d = 1.216e-10, total time: 44.0905
# t = 18, j = 0, ls_iter = 1, eps_b = 0.001487, eps_c = 5.054e-08, eps_d = 1.25e-10, darea = -1.563e-09
# Save geo18.mat at j = 1, eps_b = 0.001487, eps_c = 5.054e-08, eps_d = 1.25e-10, total time: 45.8594
# t = 19, j = 0, ls_iter = 1, eps_b = 0.001226, eps_c = 5.199e-08, eps_d = 1.272e-10, darea = -1.591e-09
# Save geo19.mat at j = 1, eps_b = 0.001226, eps_c = 5.199e-08, eps_d = 1.272e-10, total time: 47.6783
# t = 20, j = 0, ls_iter = 1, eps_b = 0.00102, eps_c = 5.391e-08, eps_d = 1.288e-10, darea = -1.61e-09
# Save geo20.mat at j = 1, eps_b = 0.00102, eps_c = 5.391e-08, eps_d = 1.288e-10, total time: 49.4903
# t = 21, j = 0, ls_iter = 1, eps_b = 0.0008533, eps_c = 4.705e-08, eps_d = 1.298e-10, darea = -1.623e-09
# Save geo21.mat at j = 1, eps_b = 0.0008533, eps_c = 4.705e-08, eps_d = 1.298e-10, total time: 51.2922
# t = 22, j = 0, ls_iter = 1, eps_b = 0.0007175, eps_c = 4.778e-08, eps_d = 1.304e-10, darea = -1.631e-09
# Save geo22.mat at j = 1, eps_b = 0.0007175, eps_c = 4.778e-08, eps_d = 1.304e-10, total time: 53.1168
# t = 23, j = 0, ls_iter = 1, eps_b = 0.0006061, eps_c = 5.032e-08, eps_d = 1.307e-10, darea = -1.635e-09
# Save geo23.mat at j = 1, eps_b = 0.0006061, eps_c = 5.032e-08, eps_d = 1.307e-10, total time: 54.8962
# t = 24, j = 0, ls_iter = 1, eps_b = 0.0005142, eps_c = 4.869e-08, eps_d = 1.308e-10, darea = -1.636e-09
# Save geo24.mat at j = 1, eps_b = 0.0005142, eps_c = 4.869e-08, eps_d = 1.308e-10, total time: 56.6815
# t = 25, j = 0, ls_iter = 1, eps_b = 0.0004383, eps_c = 5.211e-08, eps_d = 1.308e-10, darea = -1.636e-09
# Save geo25.mat at j = 1, eps_b = 0.0004383, eps_c = 5.211e-08, eps_d = 1.308e-10, total time: 58.4785
# t = 26, j = 0, ls_iter = 1, eps_b = 0.0003757, eps_c = 4.863e-08, eps_d = 1.306e-10, darea = -1.634e-09
# Save geo26.mat at j = 1, eps_b = 0.0003757, eps_c = 4.863e-08, eps_d = 1.306e-10, total time: 60.2572
# t = 27, j = 0, ls_iter = 1, eps_b = 0.000324, eps_c = 5.189e-08, eps_d = 1.304e-10, darea = -1.631e-09
# Save geo27.mat at j = 1, eps_b = 0.000324, eps_c = 5.189e-08, eps_d = 1.304e-10, total time: 62.0418
# t = 28, j = 0, ls_iter = 1, eps_b = 0.0002816, eps_c = 4.974e-08, eps_d = 1.301e-10, darea = -1.627e-09
# Save geo28.mat at j = 1, eps_b = 0.0002816, eps_c = 4.974e-08, eps_d = 1.301e-10, total time: 63.8168
# t = 29, j = 0, ls_iter = 1, eps_b = 0.0002469, eps_c = 5.236e-08, eps_d = 1.297e-10, darea = -1.622e-09
# Save geo29.mat at j = 1, eps_b = 0.0002469, eps_c = 5.236e-08, eps_d = 1.297e-10, total time: 65.6017
# t = 30, j = 0, ls_iter = 1, eps_b = 0.0002186, eps_c = 4.856e-08, eps_d = 1.292e-10, darea = -1.616e-09
# Save geo30.mat at j = 1, eps_b = 0.0002186, eps_c = 4.856e-08, eps_d = 1.292e-10, total time: 67.3930
# t = 31, j = 0, ls_iter = 1, eps_b = 0.0001956, eps_c = 5.052e-08, eps_d = 1.288e-10, darea = -1.61e-09
# Save geo31.mat at j = 1, eps_b = 0.0001956, eps_c = 5.052e-08, eps_d = 1.288e-10, total time: 69.1758
# t = 32, j = 0, ls_iter = 1, eps_b = 0.0001771, eps_c = 5.001e-08, eps_d = 1.282e-10, darea = -1.604e-09
# Save geo32.mat at j = 1, eps_b = 0.0001771, eps_c = 5.001e-08, eps_d = 1.282e-10, total time: 70.9567
# t = 33, j = 0, ls_iter = 1, eps_b = 0.0001623, eps_c = 5.225e-08, eps_d = 1.277e-10, darea = -1.597e-09
# Save geo33.mat at j = 1, eps_b = 0.0001623, eps_c = 5.225e-08, eps_d = 1.277e-10, total time: 72.7306
# t = 34, j = 0, ls_iter = 1, eps_b = 0.0001504, eps_c = 5.013e-08, eps_d = 1.271e-10, darea = -1.59e-09
# Save geo34.mat at j = 1, eps_b = 0.0001504, eps_c = 5.013e-08, eps_d = 1.271e-10, total time: 74.5176
# t = 35, j = 0, ls_iter = 1, eps_b = 0.000141, eps_c = 4.741e-08, eps_d = 1.265e-10, darea = -1.582e-09
# Save geo35.mat at j = 1, eps_b = 0.000141, eps_c = 4.741e-08, eps_d = 1.265e-10, total time: 76.3334
# t = 36, j = 0, ls_iter = 1, eps_b = 0.0001334, eps_c = 4.165e-08, eps_d = 1.259e-10, darea = -1.574e-09
# Save geo36.mat at j = 1, eps_b = 0.0001334, eps_c = 4.165e-08, eps_d = 1.259e-10, total time: 78.1321
# t = 37, j = 0, ls_iter = 1, eps_b = 0.0001274, eps_c = 4.807e-08, eps_d = 1.252e-10, darea = -1.566e-09
# Save geo37.mat at j = 1, eps_b = 0.0001274, eps_c = 4.807e-08, eps_d = 1.252e-10, total time: 79.9055
# t = 38, j = 0, ls_iter = 1, eps_b = 0.0001226, eps_c = 4.588e-08, eps_d = 1.246e-10, darea = -1.558e-09
# Save geo38.mat at j = 1, eps_b = 0.0001226, eps_c = 4.588e-08, eps_d = 1.246e-10, total time: 81.6883
# t = 39, j = 0, ls_iter = 1, eps_b = 0.0001186, eps_c = 4.912e-08, eps_d = 1.239e-10, darea = -1.549e-09
# Save geo39.mat at j = 1, eps_b = 0.0001186, eps_c = 4.912e-08, eps_d = 1.239e-10, total time: 83.4670
# t = 40, j = 0, ls_iter = 1, eps_b = 0.0001154, eps_c = 4.828e-08, eps_d = 1.232e-10, darea = -1.54e-09
# Save geo40.mat at j = 1, eps_b = 0.0001154, eps_c = 4.828e-08, eps_d = 1.232e-10, total time: 85.2894
# t = 41, j = 0, ls_iter = 1, eps_b = 0.0001127, eps_c = 4.806e-08, eps_d = 1.224e-10, darea = -1.531e-09
# Save geo41.mat at j = 1, eps_b = 0.0001127, eps_c = 4.806e-08, eps_d = 1.224e-10, total time: 87.1273
# t = 42, j = 0, ls_iter = 1, eps_b = 0.0001104, eps_c = 4.525e-08, eps_d = 1.217e-10, darea = -1.522e-09
# Save geo42.mat at j = 1, eps_b = 0.0001104, eps_c = 4.525e-08, eps_d = 1.217e-10, total time: 88.9135
# t = 43, j = 0, ls_iter = 1, eps_b = 0.0001085, eps_c = 4.561e-08, eps_d = 1.209e-10, darea = -1.512e-09
# Save geo43.mat at j = 1, eps_b = 0.0001085, eps_c = 4.561e-08, eps_d = 1.209e-10, total time: 90.7000
# t = 44, j = 0, ls_iter = 1, eps_b = 0.0001067, eps_c = 4.662e-08, eps_d = 1.201e-10, darea = -1.502e-09
# Save geo44.mat at j = 1, eps_b = 0.0001067, eps_c = 4.662e-08, eps_d = 1.201e-10, total time: 92.5056
# t = 45, j = 0, ls_iter = 1, eps_b = 0.0001052, eps_c = 4.857e-08, eps_d = 1.193e-10, darea = -1.492e-09
# Save geo45.mat at j = 1, eps_b = 0.0001052, eps_c = 4.857e-08, eps_d = 1.193e-10, total time: 94.3261
# t = 46, j = 0, ls_iter = 1, eps_b = 0.0001038, eps_c = 4.51e-08, eps_d = 1.185e-10, darea = -1.481e-09
# Save geo46.mat at j = 1, eps_b = 0.0001038, eps_c = 4.51e-08, eps_d = 1.185e-10, total time: 96.1328
# t = 47, j = 0, ls_iter = 1, eps_b = 0.0001025, eps_c = 4.2e-08, eps_d = 1.176e-10, darea = -1.471e-09
# Save geo47.mat at j = 1, eps_b = 0.0001025, eps_c = 4.2e-08, eps_d = 1.176e-10, total time: 98.0101
# t = 48, j = 0, ls_iter = 1, eps_b = 0.0001013, eps_c = 4.448e-08, eps_d = 1.167e-10, darea = -1.46e-09
# Save geo48.mat at j = 1, eps_b = 0.0001013, eps_c = 4.448e-08, eps_d = 1.167e-10, total time: 99.9452
# t = 49, j = 0, ls_iter = 1, eps_b = 0.0001002, eps_c = 4.127e-08, eps_d = 1.159e-10, darea = -1.449e-09
# Save geo49.mat at j = 1, eps_b = 0.0001002, eps_c = 4.127e-08, eps_d = 1.159e-10, total time: 101.9191
# t = 50, j = 0, ls_iter = 1, eps_b = 9.908e-05, eps_c = 4.13e-08, eps_d = 1.149e-10, darea = -1.438e-09
# Save geo50.mat at j = 1, eps_b = 9.908e-05, eps_c = 4.13e-08, eps_d = 1.149e-10, total time: 103.7943
# t = 51, j = 0, ls_iter = 1, eps_b = 9.805e-05, eps_c = 4.463e-08, eps_d = 1.14e-10, darea = -1.426e-09
# Save geo51.mat at j = 1, eps_b = 9.805e-05, eps_c = 4.463e-08, eps_d = 1.14e-10, total time: 105.7517
# t = 52, j = 0, ls_iter = 1, eps_b = 9.704e-05, eps_c = 4.15e-08, eps_d = 1.131e-10, darea = -1.414e-09
# Save geo52.mat at j = 1, eps_b = 9.704e-05, eps_c = 4.15e-08, eps_d = 1.131e-10, total time: 107.7821
# t = 53, j = 0, ls_iter = 1, eps_b = 9.607e-05, eps_c = 3.79e-08, eps_d = 1.121e-10, darea = -1.402e-09
# Save geo53.mat at j = 1, eps_b = 9.607e-05, eps_c = 3.79e-08, eps_d = 1.121e-10, total time: 109.8220
# t = 54, j = 0, ls_iter = 1, eps_b = 9.512e-05, eps_c = 4.331e-08, eps_d = 1.111e-10, darea = -1.39e-09
# Save geo54.mat at j = 1, eps_b = 9.512e-05, eps_c = 4.331e-08, eps_d = 1.111e-10, total time: 111.8429
# t = 55, j = 0, ls_iter = 1, eps_b = 9.419e-05, eps_c = 4.246e-08, eps_d = 1.101e-10, darea = -1.377e-09
# Save geo55.mat at j = 1, eps_b = 9.419e-05, eps_c = 4.246e-08, eps_d = 1.101e-10, total time: 113.8701
# t = 56, j = 0, ls_iter = 1, eps_b = 9.328e-05, eps_c = 4.093e-08, eps_d = 1.091e-10, darea = -1.365e-09
# Save geo56.mat at j = 1, eps_b = 9.328e-05, eps_c = 4.093e-08, eps_d = 1.091e-10, total time: 115.8332
# t = 57, j = 0, ls_iter = 1, eps_b = 9.238e-05, eps_c = 4.125e-08, eps_d = 1.081e-10, darea = -1.351e-09
# Save geo57.mat at j = 1, eps_b = 9.238e-05, eps_c = 4.125e-08, eps_d = 1.081e-10, total time: 117.6836
# t = 58, j = 0, ls_iter = 1, eps_b = 9.15e-05, eps_c = 3.983e-08, eps_d = 1.07e-10, darea = -1.338e-09
# Save geo58.mat at j = 1, eps_b = 9.15e-05, eps_c = 3.983e-08, eps_d = 1.07e-10, total time: 119.5298
# t = 59, j = 0, ls_iter = 1, eps_b = 9.063e-05, eps_c = 3.923e-08, eps_d = 1.059e-10, darea = -1.325e-09
# Save geo59.mat at j = 1, eps_b = 9.063e-05, eps_c = 3.923e-08, eps_d = 1.059e-10, total time: 121.3640
# t = 60, j = 0, ls_iter = 1, eps_b = 8.977e-05, eps_c = 4.019e-08, eps_d = 1.048e-10, darea = -1.311e-09
# Save geo60.mat at j = 1, eps_b = 8.977e-05, eps_c = 4.019e-08, eps_d = 1.048e-10, total time: 123.1645
# t = 61, j = 0, ls_iter = 1, eps_b = 8.891e-05, eps_c = 4.111e-08, eps_d = 1.037e-10, darea = -1.297e-09
# Save geo61.mat at j = 1, eps_b = 8.891e-05, eps_c = 4.111e-08, eps_d = 1.037e-10, total time: 124.9507
# t = 62, j = 0, ls_iter = 1, eps_b = 8.807e-05, eps_c = 4.172e-08, eps_d = 1.025e-10, darea = -1.283e-09
# Save geo62.mat at j = 1, eps_b = 8.807e-05, eps_c = 4.172e-08, eps_d = 1.025e-10, total time: 126.7388
# t = 63, j = 0, ls_iter = 1, eps_b = 8.724e-05, eps_c = 3.966e-08, eps_d = 1.014e-10, darea = -1.268e-09
# Save geo63.mat at j = 1, eps_b = 8.724e-05, eps_c = 3.966e-08, eps_d = 1.014e-10, total time: 128.5221
# t = 64, j = 0, ls_iter = 1, eps_b = 8.642e-05, eps_c = 3.889e-08, eps_d = 1.002e-10, darea = -1.253e-09
# Save geo64.mat at j = 1, eps_b = 8.642e-05, eps_c = 3.889e-08, eps_d = 1.002e-10, total time: 130.3459
# t = 65, j = 0, ls_iter = 1, eps_b = 8.561e-05, eps_c = 3.934e-08, eps_d = 9.9e-11, darea = -1.238e-09
# Save geo65.mat at j = 1, eps_b = 8.561e-05, eps_c = 3.934e-08, eps_d = 9.9e-11, total time: 132.1746
# t = 66, j = 0, ls_iter = 1, eps_b = 8.481e-05, eps_c = 4.08e-08, eps_d = 9.777e-11, darea = -1.223e-09
# Save geo66.mat at j = 1, eps_b = 8.481e-05, eps_c = 4.08e-08, eps_d = 9.777e-11, total time: 133.9471
# t = 67, j = 0, ls_iter = 1, eps_b = 8.401e-05, eps_c = 3.696e-08, eps_d = 9.652e-11, darea = -1.207e-09
# Save geo67.mat at j = 1, eps_b = 8.401e-05, eps_c = 3.696e-08, eps_d = 9.652e-11, total time: 135.7176
# t = 68, j = 0, ls_iter = 1, eps_b = 8.322e-05, eps_c = 3.968e-08, eps_d = 9.525e-11, darea = -1.191e-09
# Save geo68.mat at j = 1, eps_b = 8.322e-05, eps_c = 3.968e-08, eps_d = 9.525e-11, total time: 137.4869
# t = 69, j = 0, ls_iter = 1, eps_b = 8.243e-05, eps_c = 3.703e-08, eps_d = 9.396e-11, darea = -1.175e-09
# Save geo69.mat at j = 1, eps_b = 8.243e-05, eps_c = 3.703e-08, eps_d = 9.396e-11, total time: 139.2636
# t = 70, j = 0, ls_iter = 1, eps_b = 8.166e-05, eps_c = 3.816e-08, eps_d = 9.264e-11, darea = -1.159e-09
# Save geo70.mat at j = 1, eps_b = 8.166e-05, eps_c = 3.816e-08, eps_d = 9.264e-11, total time: 141.0970
# t = 71, j = 0, ls_iter = 1, eps_b = 8.089e-05, eps_c = 3.803e-08, eps_d = 9.131e-11, darea = -1.142e-09
# Save geo71.mat at j = 1, eps_b = 8.089e-05, eps_c = 3.803e-08, eps_d = 9.131e-11, total time: 142.9249
# t = 72, j = 0, ls_iter = 1, eps_b = 8.014e-05, eps_c = 3.837e-08, eps_d = 8.995e-11, darea = -1.125e-09
# Save geo72.mat at j = 1, eps_b = 8.014e-05, eps_c = 3.837e-08, eps_d = 8.995e-11, total time: 144.7592
# t = 73, j = 0, ls_iter = 1, eps_b = 7.938e-05, eps_c = 3.673e-08, eps_d = 8.857e-11, darea = -1.108e-09
# Save geo73.mat at j = 1, eps_b = 7.938e-05, eps_c = 3.673e-08, eps_d = 8.857e-11, total time: 146.5530
# t = 74, j = 0, ls_iter = 1, eps_b = 7.863e-05, eps_c = 3.673e-08, eps_d = 8.716e-11, darea = -1.09e-09
# Save geo74.mat at j = 1, eps_b = 7.863e-05, eps_c = 3.673e-08, eps_d = 8.716e-11, total time: 148.3702
# t = 75, j = 0, ls_iter = 1, eps_b = 7.79e-05, eps_c = 3.648e-08, eps_d = 8.574e-11, darea = -1.072e-09
# Save geo75.mat at j = 1, eps_b = 7.79e-05, eps_c = 3.648e-08, eps_d = 8.574e-11, total time: 150.3190
# t = 76, j = 0, ls_iter = 1, eps_b = 7.717e-05, eps_c = 3.819e-08, eps_d = 8.429e-11, darea = -1.054e-09
# Save geo76.mat at j = 1, eps_b = 7.717e-05, eps_c = 3.819e-08, eps_d = 8.429e-11, total time: 152.2697
# t = 77, j = 0, ls_iter = 1, eps_b = 7.645e-05, eps_c = 3.479e-08, eps_d = 8.281e-11, darea = -1.036e-09
# Save geo77.mat at j = 1, eps_b = 7.645e-05, eps_c = 3.479e-08, eps_d = 8.281e-11, total time: 154.2112
# t = 78, j = 0, ls_iter = 1, eps_b = 7.573e-05, eps_c = 3.356e-08, eps_d = 8.131e-11, darea = -1.017e-09
# Save geo78.mat at j = 1, eps_b = 7.573e-05, eps_c = 3.356e-08, eps_d = 8.131e-11, total time: 156.1410
# t = 79, j = 0, ls_iter = 1, eps_b = 7.503e-05, eps_c = 3.298e-08, eps_d = 7.979e-11, darea = -9.979e-10
# Save geo79.mat at j = 1, eps_b = 7.503e-05, eps_c = 3.298e-08, eps_d = 7.979e-11, total time: 157.9242
# t = 80, j = 0, ls_iter = 1, eps_b = 7.433e-05, eps_c = 3.616e-08, eps_d = 7.825e-11, darea = -9.786e-10
# Save geo80.mat at j = 1, eps_b = 7.433e-05, eps_c = 3.616e-08, eps_d = 7.825e-11, total time: 159.7005
# t = 81, j = 0, ls_iter = 1, eps_b = 7.363e-05, eps_c = 3.424e-08, eps_d = 7.667e-11, darea = -9.589e-10
# Save geo81.mat at j = 1, eps_b = 7.363e-05, eps_c = 3.424e-08, eps_d = 7.667e-11, total time: 161.4707
# t = 82, j = 0, ls_iter = 1, eps_b = 7.294e-05, eps_c = 3.318e-08, eps_d = 7.508e-11, darea = -9.39e-10
# Save geo82.mat at j = 1, eps_b = 7.294e-05, eps_c = 3.318e-08, eps_d = 7.508e-11, total time: 163.2408
# t = 83, j = 0, ls_iter = 1, eps_b = 7.226e-05, eps_c = 3.481e-08, eps_d = 7.346e-11, darea = -9.187e-10
# Save geo83.mat at j = 1, eps_b = 7.226e-05, eps_c = 3.481e-08, eps_d = 7.346e-11, total time: 165.0115
# t = 84, j = 0, ls_iter = 1, eps_b = 7.159e-05, eps_c = 3.055e-08, eps_d = 7.181e-11, darea = -8.981e-10
# Save geo84.mat at j = 1, eps_b = 7.159e-05, eps_c = 3.055e-08, eps_d = 7.181e-11, total time: 166.7698
# t = 85, j = 0, ls_iter = 1, eps_b = 7.092e-05, eps_c = 3.58e-08, eps_d = 7.014e-11, darea = -8.772e-10
# Save geo85.mat at j = 1, eps_b = 7.092e-05, eps_c = 3.58e-08, eps_d = 7.014e-11, total time: 168.5654
# t = 86, j = 0, ls_iter = 1, eps_b = 7.026e-05, eps_c = 2.997e-08, eps_d = 6.844e-11, darea = -8.56e-10
# Save geo86.mat at j = 1, eps_b = 7.026e-05, eps_c = 2.997e-08, eps_d = 6.844e-11, total time: 170.3850
# t = 87, j = 0, ls_iter = 1, eps_b = 6.961e-05, eps_c = 3.3e-08, eps_d = 6.672e-11, darea = -8.344e-10
# Save geo87.mat at j = 1, eps_b = 6.961e-05, eps_c = 3.3e-08, eps_d = 6.672e-11, total time: 172.3557
# t = 88, j = 0, ls_iter = 1, eps_b = 6.896e-05, eps_c = 3.205e-08, eps_d = 6.497e-11, darea = -8.126e-10
# Save geo88.mat at j = 1, eps_b = 6.896e-05, eps_c = 3.205e-08, eps_d = 6.497e-11, total time: 174.2018
# t = 89, j = 0, ls_iter = 1, eps_b = 6.832e-05, eps_c = 3.288e-08, eps_d = 6.319e-11, darea = -7.903e-10
# Save geo89.mat at j = 1, eps_b = 6.832e-05, eps_c = 3.288e-08, eps_d = 6.319e-11, total time: 176.0078
# t = 90, j = 0, ls_iter = 1, eps_b = 6.77e-05, eps_c = 3.492e-08, eps_d = 6.139e-11, darea = -7.678e-10
# Save geo90.mat at j = 1, eps_b = 6.77e-05, eps_c = 3.492e-08, eps_d = 6.139e-11, total time: 177.8089
# t = 91, j = 0, ls_iter = 1, eps_b = 6.706e-05, eps_c = 3.108e-08, eps_d = 5.956e-11, darea = -7.449e-10
# Save geo91.mat at j = 1, eps_b = 6.706e-05, eps_c = 3.108e-08, eps_d = 5.956e-11, total time: 179.6027
