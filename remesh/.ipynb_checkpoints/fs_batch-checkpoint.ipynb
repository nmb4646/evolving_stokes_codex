# %%
#!/usr/bin/env python3

import itertools
import os
import sys
import time
import signal
import subprocess
import threading
from dataclasses import dataclass

import numpy as np


# ============================================================
# User configuration
# ============================================================

here = "/home/nickbroussinos/Code/evolving_stokes_codex/remesh/"

verbose = "false"
resume = True
supress_outputs = 0

precond = 1
subdivisions = 12
roughness = 0
remesh_size = 0

T = 10000
k = 100
# Da, Sd, and gamy can each be a scalar, list/tuple, or numpy array.
Da = [0]
Sd = [.1, 1, 2, 3, 5]
Gamma = 0
gamy = [1.11e-3]
chi = 1
dt = Sd[0]/gamy[0]
# Da = 10.0 ** np.arange(-10, -8, .5)
#gamy = 1e-3*(10.0 ** np.arange(-1, 1.2, .4))

max_workers = 6

PRE_CLEAN_OLD_BATCH_JOBS = True

LD_PRELOAD_PATH = "/usr/lib/x86_64-linux-gnu/libstdc++.so.6"


# ============================================================
# Output filtering
# ============================================================

NOISY_PATTERNS = [
    "MathWorksServiceHost",
    "GLIBCXX_3.4.31",
    "GLIBCXX_3.4.32",
    "CXXABI_1.3.15",
    "libmwflnetwork.so",
    "libmwflcrypto.so",
    "libmwflcryptoutils.so",
    "libmwflcryptoopenssl.so",
    "libmwflurlmgrfactory.so",
]


def is_noisy(line):
    return any(pattern in line for pattern in NOISY_PATTERNS)


# ============================================================
# Helpers
# ============================================================

def matlab_string(s):
    return "'" + s.replace("'", "''") + "'"


def as_float_list(value, name):
    if isinstance(value, np.ndarray):
        values = value.astype(float).ravel().tolist()
    elif isinstance(value, (list, tuple)):
        values = [float(v) for v in value]
    else:
        values = [float(value)]

    if not values:
        raise ValueError(f"{name} sweep list is empty")

    return values


Da_values = as_float_list(Da, "Da")
Sd_values = as_float_list(Sd, "Sd")
gamy_values = as_float_list(gamy, "gamy")


def lastFrame(directory):
    frames = []

    for file in os.listdir(directory):
        if file.startswith("geo") and file.endswith(".mat"):
            try:
                frame = int(file.split("geo")[1].split(".")[0])
                frames.append(frame)
            except Exception:
                pass

    return max(frames) if frames else 0


def make_run_tag(Da_value, Sd_value, gamy_value):
    return (
        f"Sd_{Sd_value:.2e}_Da_{Da_value:.2e}_gamy_{gamy_value:+.2e}"
        .replace("+", "p")
        .replace("-", "m")
    )


def make_matlab_command(Da_value, Sd_value, gamy_value, dir_path, start):
    """
    Build a single-line MATLAB command for -r.

    This avoids:
      - shell=True
      - MATLAB -batch multiline parsing
      - generated .m driver files
    """

    pieces = [
        "try",
        f"cd({matlab_string(here)})",
        f"verbose = {verbose}",
        f"supress_outputs = {supress_outputs}",
        f"dir = {matlab_string(dir_path + '/')}",
        f"start = {start}",
        "p = struct()",
        f"p.roughness = {roughness}",
        f"p.dt = {dt}",
        f"p.T = {T}",
        f"p.start = {start}",
        f"p.subdivisions = {subdivisions}",
        f"p.k = {k}",
        f"p.remesh_size = {remesh_size}",
        f"p.precondition_system = {precond}",
        f"p.Da = {Da_value:.17g}",
        f"p.Sd = {Sd_value:.17g}",
        f"p.Gamma = {Gamma:.17g}",
        f"p.gamy = {gamy_value:.17g}",
        f"p.chi = {chi:.17g}",
        "fs_multi",
        "exit(0)",
        "catch ME",
        "disp(getReport(ME, 'extended'))",
        "exit(1)",
        "end",
    ]

    cmd = "; ".join(pieces)

    try:
        cmd.encode("ascii")
    except UnicodeEncodeError as e:
        raise RuntimeError(f"Non-ASCII character in MATLAB command: {e}") from e

    return cmd


@dataclass
class Job:
    run_tag: str
    Da: float
    Sd: float
    gamy: float
    dir_path: str
    log_path: str
    matlab_command: str


@dataclass
class RunningJob:
    job: Job
    process: subprocess.Popen
    log_file: object
    reader_thread: threading.Thread


def build_jobs():
    jobs = []

    for Da_value, Sd_value, gamy_value in itertools.product(Da_values, Sd_values, gamy_values):
        run_tag = make_run_tag(Da_value, Sd_value, gamy_value)
        dir_path = os.path.join(here, "data", "fs_batch_data", run_tag)
        os.makedirs(dir_path, exist_ok=True)

        start = lastFrame(dir_path) if resume else 0

        if resume:
            print(f"[{run_tag}] resume start frame: {start}")

        log_path = os.path.join(dir_path, "matlab.log")
        matlab_command = make_matlab_command(Da_value, Sd_value, gamy_value, dir_path, start)

        jobs.append(
            Job(
                run_tag=run_tag,
                Da=Da_value,
                Sd=Sd_value,
                gamy=gamy_value,
                dir_path=dir_path,
                log_path=log_path,
                matlab_command=matlab_command,
            )
        )

    return jobs


# ============================================================
# Old-job cleanup
# ============================================================

def find_old_batch_process_groups():
    current_pgid = os.getpgrp()

    result = subprocess.run(
        ["ps", "-u", str(os.getuid()), "-o", "pid=,ppid=,pgid=,command="],
        text=True,
        stdout=subprocess.PIPE,
        stderr=subprocess.DEVNULL,
    )

    pgids = set()

    for line in result.stdout.splitlines():
        parts = line.strip().split(maxsplit=3)

        if len(parts) < 4:
            continue

        try:
            pid = int(parts[0])
            pgid = int(parts[2])
        except ValueError:
            continue

        cmd = parts[3]

        if pid == os.getpid():
            continue

        if pgid == current_pgid:
            continue

        cmd_lower = cmd.lower()

        is_old_inline_batch = "fs_multi" in cmd and here in cmd
        is_old_driver_batch = "_fs_batch_driver.m" in cmd and here in cmd
        is_batch_data_matlab = "matlab" in cmd_lower and "fs_batch_data" in cmd and here in cmd

        if is_old_inline_batch or is_old_driver_batch or is_batch_data_matlab:
            pgids.add(pgid)

    return pgids


def process_group_exists(pgid):
    try:
        os.killpg(pgid, 0)
        return True
    except ProcessLookupError:
        return False
    except PermissionError:
        return True


def kill_process_group(pgid, label="", grace_seconds=5.0):
    if not process_group_exists(pgid):
        return

    prefix = f"{label}: " if label else ""

    print(f"{prefix}killing process group {pgid} with SIGTERM", file=sys.stderr)

    try:
        os.killpg(pgid, signal.SIGTERM)
    except ProcessLookupError:
        return

    deadline = time.time() + grace_seconds

    while time.time() < deadline:
        if not process_group_exists(pgid):
            return
        time.sleep(0.25)

    if process_group_exists(pgid):
        print(f"{prefix}process group {pgid} survived; killing with SIGKILL", file=sys.stderr)

        try:
            os.killpg(pgid, signal.SIGKILL)
        except ProcessLookupError:
            pass


def clean_old_batch_jobs():
    pgids = find_old_batch_process_groups()

    if not pgids:
        print("No old MATLAB batch process groups found.")
        return

    print("Found old MATLAB batch process groups:")

    for pgid in sorted(pgids):
        print(f"  PGID {pgid}")

    for pgid in sorted(pgids):
        kill_process_group(pgid, label="old batch")


# ============================================================
# Launching and monitoring
# ============================================================

def stream_output(running):
    process = running.process
    job = running.job
    log_file = running.log_file

    assert process.stdout is not None

    for line in process.stdout:
        log_file.write(line)
        log_file.flush()

        if not is_noisy(line):
            sys.stdout.write(f"[{job.run_tag}] {line}")
            sys.stdout.flush()


def launch_job(job):
    env = os.environ.copy()
    env["LD_PRELOAD"] = LD_PRELOAD_PATH

    log_file = open(job.log_path, "a", buffering=1, encoding="utf-8")

    log_file.write("\n")
    log_file.write("=" * 80 + "\n")
    log_file.write(f"Starting job: {job.run_tag}\n")
    log_file.write(f"Da: {job.Da}\n")
    log_file.write(f"Sd: {job.Sd}\n")
    log_file.write(f"gamy: {job.gamy}\n")
    log_file.write(f"Directory: {job.dir_path}\n")
    log_file.write("MATLAB command:\n")
    log_file.write(job.matlab_command + "\n")
    log_file.write("=" * 80 + "\n")
    log_file.flush()

    process = subprocess.Popen(
        [
            "matlab",
            "-nodisplay",
            "-nosplash",
            "-nodesktop",
            "-r",
            job.matlab_command,
        ],
        cwd=here,
        env=env,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
        start_new_session=True,
    )

    running = RunningJob(
        job=job,
        process=process,
        log_file=log_file,
        reader_thread=None,
    )

    reader_thread = threading.Thread(target=stream_output, args=(running,), daemon=True)
    running.reader_thread = reader_thread
    reader_thread.start()

    print(f"Launched {job.run_tag} with MATLAB PID {process.pid}")

    return running


def stop_running_job(running):
    process = running.process

    if process.poll() is None:
        try:
            pgid = os.getpgid(process.pid)
        except ProcessLookupError:
            pgid = process.pid

        kill_process_group(pgid, label=running.job.run_tag)

    try:
        if process.stdout is not None:
            process.stdout.close()
    except Exception:
        pass

    try:
        running.reader_thread.join(timeout=2)
    except Exception:
        pass

    try:
        running.log_file.close()
    except Exception:
        pass


def close_finished_job(running):
    returncode = running.process.returncode

    try:
        running.reader_thread.join(timeout=2)
    except Exception:
        pass

    try:
        running.log_file.write(f"\nJob exited with code {returncode}\n")
        running.log_file.flush()
        running.log_file.close()
    except Exception:
        pass

    return returncode


def run_batch(jobs, max_workers):
    pending = list(jobs)
    running = []
    failures = 0

    try:
        while pending or running:
            while pending and len(running) < max_workers:
                job = pending.pop(0)
                running.append(launch_job(job))

            still_running = []

            for rjob in running:
                returncode = rjob.process.poll()

                if returncode is None:
                    still_running.append(rjob)
                    continue

                returncode = close_finished_job(rjob)

                if returncode == 0:
                    print(f"Finished {rjob.job.run_tag}")
                else:
                    failures += 1
                    print(
                        f"FAILED {rjob.job.run_tag} with exit code {returncode}. "
                        f"See log: {rjob.job.log_path}",
                        file=sys.stderr,
                    )

            running = still_running
            time.sleep(0.5)

    except KeyboardInterrupt:
        print("\nInterrupted. Killing active MATLAB jobs...", file=sys.stderr)

        for rjob in list(running):
            stop_running_job(rjob)

        print("Stopped active MATLAB jobs.", file=sys.stderr)
        raise SystemExit(130)

    if failures:
        raise SystemExit(failures)


# ============================================================
# Main
# ============================================================

def main():
    print(f"Project directory: {here}")
    print(f"max_workers: {max_workers}")
    print(f"resume: {resume}")
    print(f"Da values: {Da_values}")
    print(f"Sd values: {Sd_values}")
    print(f"gamy values: {gamy_values}")
    print(f"number of jobs: {len(Da_values) * len(Sd_values) * len(gamy_values)}")

    if PRE_CLEAN_OLD_BATCH_JOBS:
        clean_old_batch_jobs()

    jobs = build_jobs()

    print("Jobs to run:")

    for job in jobs:
        print(f"  {job.run_tag}")

    run_batch(jobs, max_workers=max_workers)


if __name__ == "__main__":
    main()
# Out:
# Project directory: /home/nickbroussinos/Code/evolving_stokes_codex/remesh/
# max_workers: 6
# resume: True
# Da values: [0.0]
# Sd values: [0.001]
# gamy values: [0.000101, 0.000301, 0.00101, 0.00301, 0.0101]
# number of jobs: 5
# No old MATLAB batch process groups found.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] resume start frame: 1
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] resume start frame: 1
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] resume start frame: 2
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] resume start frame: 1
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] resume start frame: 1
# Jobs to run:
#   Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04
#   Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04
#   Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03
#   Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03
#   Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02
# Launched Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04 with MATLAB PID 24387
# Launched Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04 with MATLAB PID 24389
# Launched Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03 with MATLAB PID 24391
# Launched Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03 with MATLAB PID 24398
# Launched Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02 with MATLAB PID 24404
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02]                             < M A T L A B (R) >
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02]                   Copyright 1984-2024 The MathWorks, Inc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02]              R2024a Update 3 (24.1.0.2603908) 64-bit (glnxa64)
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02]                                 May 2, 2024
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02]
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03]
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03]                             < M A T L A B (R) >
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03]                   Copyright 1984-2024 The MathWorks, Inc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03]              R2024a Update 3 (24.1.0.2603908) 64-bit (glnxa64)
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03]                                 May 2, 2024
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03]                             < M A T L A B (R) >
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03]                   Copyright 1984-2024 The MathWorks, Inc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03]              R2024a Update 3 (24.1.0.2603908) 64-bit (glnxa64)
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03]                                 May 2, 2024
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04]                             < M A T L A B (R) >
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04]                   Copyright 1984-2024 The MathWorks, Inc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04]              R2024a Update 3 (24.1.0.2603908) 64-bit (glnxa64)
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04]                                 May 2, 2024
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04]
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04]
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04]                             < M A T L A B (R) >
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04]                   Copyright 1984-2024 The MathWorks, Inc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04]              R2024a Update 3 (24.1.0.2603908) 64-bit (glnxa64)
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04]                                 May 2, 2024
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] To get started, type doc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] For product information, visit www.mathworks.com.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02]
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03]
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] To get started, type doc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] For product information, visit www.mathworks.com.
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] To get started, type doc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] For product information, visit www.mathworks.com.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04]
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] To get started, type doc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] For product information, visit www.mathworks.com.
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04]
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04]
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] To get started, type doc.
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] For product information, visit www.mathworks.com.
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04]
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 2
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo2.mat at j = 2, eps_b = 6.287e-08, eps_c = 9.693e-18, eps_d = 2.672e-13, total time: 74.8215
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 2
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo2.mat at j = 3, eps_b = 1.503e-08, eps_c = 3.243e-18, eps_d = 5.244e-15, total time: 88.6031
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 2
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 2
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo2.mat at j = 3, eps_b = 1.13e-08, eps_c = 3.185e-16, eps_d = 1.008e-15, total time: 89.7593
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo2.mat at j = 3, eps_b = 5.072e-09, eps_c = 9.502e-17, eps_d = 4.034e-16, total time: 90.5888
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 3
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo3.mat at j = 3, eps_b = 3.008e-09, eps_c = 3.212e-17, eps_d = 4.034e-16, total time: 123.2048
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 3
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo3.mat at j = 3, eps_b = 2.024e-08, eps_c = 9.884e-18, eps_d = 1.351e-14, total time: 138.9137
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 3
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo3.mat at j = 3, eps_b = 3.05e-08, eps_c = 3.233e-16, eps_d = 4.034e-16, total time: 152.6359
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 4
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 3
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save ge
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo46.mat at j = 2, eps_b = 2.225e-08, eps_c = 3.275e-17, eps_d = 1.21e-15, total time: 2215.9061
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 36
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo36.mat at j = 3, eps_b = 9.82e-10, eps_c = 9.72e-17, eps_d = 4.034e-16, total time: 2202.2817
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 48
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo48.mat at j = 2, eps_b = 1.388e-09, eps_c = 9.904e-18, eps_d = 8.067e-16, total time: 2196.6191
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 43
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo43.mat at j = 2, eps_b = 2.007e-08, eps_c = 3.271e-18, eps_d = 1.311e-14, total time: 2215.5593
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 47
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo47.mat at j = 2, eps_b = 2.17e-08, eps_c = 3.24e-17, eps_d = 1.21e-15, total time: 2261.2354
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 49
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo49.mat at j = 2, eps_b = 8.528e-10, eps_c = 9.912e-18, eps_d = 2.017e-16, total time: 2241.9235
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 37
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo37.mat at j = 3, eps_b = 3.929e-09, eps_c = 3.254e-16, eps_d = 4.034e-16, total time: 2249.8761
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 37
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo37.mat at j = 3, eps_b = 9.122e-10, eps_c = 9.624e-17, eps_d = 0, total time: 2264.1812
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 44
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo44.mat at j = 2, eps_b = 2.032e-08, eps_c = 3.254e-18, eps_d = 1.371e-14, total time: 2261.7373
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 48
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo48.mat at j = 2, eps_b = 2.663e-08, eps_c = 3.223e-17, eps_d = 2.824e-15, total time: 2306.0203
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 50
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo50.mat at j = 2, eps_b = 5.86e-10, eps_c = 9.625e-18, eps_d = 0, total time: 2287.1148
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 45
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 38
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo45.mat at j = 2, eps_b = 2.146e-08, eps_c = 3.214e-18, eps_d = 1.492e-14, total time: 2306.8427
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo38.mat at j = 3, eps_b = 5.07e-09, eps_c = 3.234e-16, eps_d = 0, total time: 2309.9665
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 49
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 38
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo49.mat at j = 2, eps_b = 2.407e-08, eps_c = 3.298e-17, eps_d = 1.815e-15, total time: 2351.7956
# ...
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo350.mat at j = 2, eps_b = 5.042e-10, eps_c = 9.822e-18, eps_d = 4.034e-16, total time: 15035.8131
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 317
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo317.mat at j = 2, eps_b = 1.532e-08, eps_c = 3.275e-18, eps_d = 5.244e-15, total time: 15065.2985
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 242
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo242.mat at j = 3, eps_b = 1.604e-09, eps_c = 9.729e-17, eps_d = 8.067e-16, total time: 15143.8919
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 328
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo328.mat at j = 2, eps_b = 2.832e-08, eps_c = 3.316e-17, eps_d = 2.824e-15, total time: 15131.7785
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 351
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo351.mat at j = 2, eps_b = 3.707e-10, eps_c = 9.771e-18, eps_d = 0, total time: 15082.3050
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 243
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo243.mat at j = 3, eps_b = 6.328e-09, eps_c = 3.307e-16, eps_d = 1.008e-15, total time: 15153.9321
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 318
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo318.mat at j = 3, eps_b = 1.084e-08, eps_c = 3.3e-18, eps_d = 3.025e-15, total time: 15130.7351
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 329
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo329.mat at j = 2, eps_b = 3.059e-08, eps_c = 3.272e-17, eps_d = 2.42e-15, total time: 15175.6634
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 352
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo352.mat at j = 2, eps_b = 2.815e-10, eps_c = 9.567e-18, eps_d = 0, total time: 15128.7534
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 243
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo243.mat at j = 3, eps_b = 1.213e-09, eps_c = 9.783e-17, eps_d = 8.067e-16, total time: 15207.0206
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 244
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo244.mat at j = 3, eps_b = 5.58e-09, eps_c = 3.292e-16, eps_d = 4.034e-16, total time: 15215.6761
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 330
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo330.mat at j = 2, eps_b = 3.146e-08, eps_c = 3.314e-17, eps_d = 3.227e-15, total time: 15219.6971
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 353
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo353.mat at j = 2, eps_b = 2.303e-10, eps_c = 9.768e-18, eps_d = 6.051e-16, total time: 15175.0763
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 319
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo319.mat at j = 3, eps_b = 7.928e-09, eps_c = 3.271e-18, eps_d = 3.025e-15, total time: 15196.4216
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 244
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo244.mat at j = 3, eps_b = 2.005e-09, eps_c = 9.862e-17, eps_d = 6.051e-16, total time: 15268.8101
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 245
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo245.mat at j = 3, eps_b = 5.211e-09, eps_c = 3.299e-16, eps_d = 2.017e-16, total time: 15278.6135
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 331
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo331.mat at j = 2, eps_b = 2.472e-08, eps_c = 3.315e-17, eps_d = 1.613e-15, total time: 15265.5151
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 354
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo354.mat at j = 2, eps_b = 2.415e-10, eps_c = 9.866e-18, eps_d = 6.051e-16, total time: 15220.1337
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 320
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo320.mat at j = 3, eps_b = 3.866e-09, eps_c = 3.319e-18, eps_d = 1.21e-15, total time: 15258.3721
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 245
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo245.mat at j = 3, eps_b = 2.157e-09, eps_c = 9.899e-17, eps_d = 1.613e-15, total time: 15331.5806
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 332
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo332.mat at j = 2, eps_b = 2.262e-08, eps_c = 3.334e-17, eps_d = 1.613e-15, total time: 15310.7296
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 355
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo355.mat at j = 2, eps_b = 1.627e-10, eps_c = 9.857e-18, eps_d = 1.21e-15, total time: 15264.4845
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 246
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo246.mat at j = 3, eps_b = 6.418e-09, eps_c = 3.343e-16, eps_d = 6.051e-16, total time: 15342.1224
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 321
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo321.mat at j = 3, eps_b = 1.974e-09, eps_c = 3.332e-18, eps_d = 4.034e-16, total time: 15322.7956
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 333
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo333.mat at j = 2, eps_b = 2.918e-08, eps_c = 3.347e-17, eps_d = 1.613e-15, total time: 15355.1547
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 356
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo356.mat at j = 2, eps_b = 1.244e-10, eps_c = 9.82e-18, eps_d = 4.034e-16, total time: 15309.8840
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 246
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo246.mat at j = 3, eps_b = 1.962e-09, eps_c = 9.916e-17, eps_d = 0, total time: 15395.2772
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 247
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo247.mat at j = 3, eps_b = 7.209e-09, eps_c = 3.336e-16, eps_d = 6.051e-16, total time: 15402.9438
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 334
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo334.mat at j = 2, eps_b = 2.737e-08, eps_c = 3.273e-17, eps_d = 2.42e-15, total time: 15402.8302
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 357
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo357.mat at j = 2, eps_b = 1.159e-10, eps_c = 9.826e-18, eps_d = 4.034e-16, total time: 15357.0775
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Remeshing. t = 322
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04] Save geo322.mat at j = 3, eps_b = 1.012e-09, eps_c = 3.282e-18, eps_d = 4.034e-16, total time: 15389.2215
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 247
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo247.mat at j = 3, eps_b = 1.705e-09, eps_c = 9.732e-17, eps_d = 6.051e-16, total time: 15459.8708
# Interrupted. Killing active MATLAB jobs...
# Sd_1.00em03_Da_0.00ep00_gamy_p1.01em04: killing process group 24387 with SIGTERM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 472, in run_batch(jobs, max_workers)
#     471         running = still_running
# --> 472         time.sleep(0.5)
#     474 except KeyboardInterrupt:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 514
#     510     run_batch(jobs, max_workers=max_workers)
#     513 if __name__ == "__main__":
# --> 514     main()
#
# Cell In[16], line 510, in main()
#     507 for job in jobs:
#     508     print(f"  {job.run_tag}")
# --> 510 run_batch(jobs, max_workers=max_workers)
#
# Cell In[16], line 478, in run_batch(jobs, max_workers)
#     475 print("\nInterrupted. Killing active MATLAB jobs...", file=sys.stderr)
#     477 for rjob in list(running):
# --> 478     stop_running_job(rjob)
#     480 print("Stopped active MATLAB jobs.", file=sys.stderr)
#     481 raise SystemExit(130)
#
# Cell In[16], line 402, in stop_running_job(running)
#     399     except ProcessLookupError:
#     400         pgid = process.pid
# --> 402     kill_process_group(pgid, label=running.job.run_tag)
#     404 try:
#     405     if process.stdout is not None:
#
# Cell In[16], line 294, in kill_process_group(pgid, label, grace_seconds)
#     292     if not process_group_exists(pgid):
#     293         return
# --> 294     time.sleep(0.25)
#     296 if process_group_exists(pgid):
#     297     print(f"{prefix}process group {pgid} survived; killing with SIGKILL", file=sys.stderr)
#
# KeyboardInterrupt:
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 248
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo248.mat at j = 3, eps_b = 6.165e-09, eps_c = 3.346e-16, eps_d = 0, total time: 15466.5676
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 335
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo335.mat at j = 2, eps_b = 3.099e-08, eps_c = 3.323e-17, eps_d = 3.025e-15, total time: 15448.4465
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 358
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo358.mat at j = 2, eps_b = 1.325e-10, eps_c = 9.72e-18, eps_d = 1.613e-15, total time: 15401.9519
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 336
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo336.mat at j = 2, eps_b = 2.456e-08, eps_c = 3.253e-17, eps_d = 8.067e-16, total time: 15488.3357
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 248
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo248.mat at j = 3, eps_b = 1.435e-09, eps_c = 9.889e-17, eps_d = 4.034e-16, total time: 15516.3780
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 359
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo359.mat at j = 2, eps_b = 9.194e-11, eps_c = 9.815e-18, eps_d = 4.034e-16, total time: 15442.3900
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 249
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo249.mat at j = 3, eps_b = 6.056e-09, eps_c = 3.301e-16, eps_d = 2.017e-16, total time: 15522.4870
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 337
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo337.mat at j = 2, eps_b = 2.928e-08, eps_c = 3.293e-17, eps_d = 3.832e-15, total time: 15528.7982
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 360
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo360.mat at j = 2, eps_b = 9.049e-11, eps_c = 9.862e-18, eps_d = 4.034e-16, total time: 15481.4864
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 249
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo249.mat at j = 3, eps_b = 1.699e-09, eps_c = 9.791e-17, eps_d = 2.017e-16, total time: 15571.0595
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 250
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo250.mat at j = 3, eps_b = 6.369e-09, eps_c = 3.242e-16, eps_d = 2.017e-16, total time: 15576.7905
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 338
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo338.mat at j = 2, eps_b = 3.607e-08, eps_c = 3.316e-17, eps_d = 3.429e-15, total time: 15569.0061
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 361
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo361.mat at j = 2, eps_b = 1.082e-10, eps_c = 9.899e-18, eps_d = 0, total time: 15520.7104
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 250
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo250.mat at j = 3, eps_b = 2.313e-09, eps_c = 9.873e-17, eps_d = 4.034e-16, total time: 15626.0225
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 339
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo339.mat at j = 2, eps_b = 3.004e-08, eps_c = 3.251e-17, eps_d = 3.429e-15, total time: 15608.7784
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 251
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo251.mat at j = 3, eps_b = 7.128e-09, eps_c = 3.289e-16, eps_d = 2.017e-16, total time: 15633.0569
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 362
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo362.mat at j = 2, eps_b = 9.124e-11, eps_c = 9.874e-18, eps_d = 0, total time: 15560.6858
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 340
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo340.mat at j = 2, eps_b = 2.216e-08, eps_c = 3.3e-17, eps_d = 1.21e-15, total time: 15650.0064
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 363
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo363.mat at j = 2, eps_b = 5.425e-11, eps_c = 9.896e-18, eps_d = 1.21e-15, total time: 15601.1517
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 251
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo251.mat at j = 3, eps_b = 1.734e-09, eps_c = 9.745e-17, eps_d = 0, total time: 15683.2215
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 252
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo252.mat at j = 3, eps_b = 6.253e-09, eps_c = 3.277e-16, eps_d = 2.017e-16, total time: 15688.4779
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 341
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo341.mat at j = 2, eps_b = 2.707e-08, eps_c = 3.313e-17, eps_d = 3.025e-15, total time: 15691.1454
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 364
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo364.mat at j = 2, eps_b = 4.933e-11, eps_c = 9.626e-18, eps_d = 0, total time: 15641.4578
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 252
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo252.mat at j = 3, eps_b = 1.351e-09, eps_c = 9.829e-17, eps_d = 8.067e-16, total time: 15736.4077
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 253
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo253.mat at j = 3, eps_b = 7.49e-09, eps_c = 3.255e-16, eps_d = 4.034e-16, total time: 15743.8042
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 342
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo342.mat at j = 2, eps_b = 2.888e-08, eps_c = 3.314e-17, eps_d = 2.42e-15, total time: 15730.2787
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 365
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo365.mat at j = 2, eps_b = 5.631e-11, eps_c = 9.845e-18, eps_d = 2.017e-16, total time: 15682.5271
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 253
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo253.mat at j = 3, eps_b = 1.367e-09, eps_c = 9.799e-17, eps_d = 8.067e-16, total time: 15791.7615
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 343
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 366
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo343.mat at j = 2, eps_b = 2.593e-08, eps_c = 3.297e-17, eps_d = 1.412e-15, total time: 15771.7254
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo366.mat at j = 2, eps_b = 1.06e-10, eps_c = 9.812e-18, eps_d = 8.067e-16, total time: 15721.5562
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 254
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo254.mat at j = 3, eps_b = 6.636e-09, eps_c = 3.393e-16, eps_d = 4.034e-16, total time: 15799.2224
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 344
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 367
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo344.mat at j = 2, eps_b = 3.179e-08, eps_c = 3.321e-17, eps_d = 1.613e-15, total time: 15811.4299
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo367.mat at j = 2, eps_b = 3.709e-08, eps_c = 9.872e-18, eps_d = 5.93e-14, total time: 15761.3370
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Remeshing. t = 254
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em03] Save geo254.mat at j = 3, eps_b = 1.692e-09, eps_c = 9.859e-17, eps_d = 4.034e-16, total time: 15848.1855
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Remeshing. t = 255
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em02] Save geo255.mat at j = 3, eps_b = 5.464e-09, eps_c = 3.343e-16, eps_d = 6.051e-16, total time: 15852.8373
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Remeshing. t = 368
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Remeshing. t = 345
# [Sd_1.00em03_Da_0.00ep00_gamy_p3.01em04] Save geo368.mat at j = 2, eps_b = 6.689e-09, eps_c = 9.649e-18, eps_d = 6.252e-15, total time: 15801.4892
# [Sd_1.00em03_Da_0.00ep00_gamy_p1.01em03] Save geo345.mat at j = 2, eps_b = 2.874e-08, eps_c = 3.262e-17, eps_d = 1.613e-15, total time: 15852.4129
