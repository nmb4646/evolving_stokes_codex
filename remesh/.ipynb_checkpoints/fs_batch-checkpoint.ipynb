# %%
#!/usr/bin/env python3

import inspect
import itertools
import os
import sys
import time
import signal
import subprocess
import threading
from dataclasses import dataclass

import numpy as np


# ============================================================
# User configuration
# ============================================================

here = "/home/nickbroussinos/Code/evolving_stokes_codex/remesh/"

verbose = "true"
resume = True
supress_outputs = 0

precond = 1
roughness = 0
remesh_size = 0

subdivisions = 11
T = 200
k = 1e3
Da = [0]
Sd = [1e-2,3e-2,1e-1,3e-1,1e0,3e0,1e1,3e1,1e2]
Gamma = 0
gamy = [0]

v = .97
#v = [0.988940,0.97734,0.96597,0.954817,0.9438,0.93314,0.9226,0.91227,0.90213,0.89217,0.88240,0.87280]
dt = lambda Da, Sd, gamy: (Sd**(-1))/10


# sweep_mode = "product" gives all cartesian combinations.
# sweep_mode = "paired" pairs parameter arrays by index and broadcasts scalar arrays.
sweep_mode = "product"



chi = 1

max_workers = 1

PRE_CLEAN_OLD_BATCH_JOBS = True

LD_PRELOAD_PATH = "/usr/lib/x86_64-linux-gnu/libstdc++.so.6"


# ============================================================
# Output filtering
# ============================================================

NOISY_PATTERNS = [
    "MathWorksServiceHost",
    "GLIBCXX_3.4.31",
    "GLIBCXX_3.4.32",
    "CXXABI_1.3.15",
    "libmwflnetwork.so",
    "libmwflcrypto.so",
    "libmwflcryptoutils.so",
    "libmwflcryptoopenssl.so",
    "libmwflurlmgrfactory.so",
]


def is_noisy(line):
    return any(pattern in line for pattern in NOISY_PATTERNS)


# ============================================================
# Helpers
# ============================================================

def matlab_string(s):
    return "'" + s.replace("'", "''") + "'"


def as_float_list(value, name):
    if isinstance(value, np.ndarray):
        values = value.astype(float).ravel().tolist()
    elif isinstance(value, (list, tuple)):
        values = [float(v) for v in value]
    else:
        values = [float(value)]

    if not values:
        raise ValueError(f"{name} sweep list is empty")

    return values


def resolve_dt_values(dt_spec, parameter_combinations):
    """Return one dt value for each (Da, Sd, gamy, v) combination."""
    n_jobs = len(parameter_combinations)

    if callable(dt_spec):
        dt_values = [
            float(call_dt_function(dt_spec, Da_value, Sd_value, gamy_value, v_value))
            for Da_value, Sd_value, gamy_value, v_value in parameter_combinations
        ]
    elif isinstance(dt_spec, np.ndarray):
        dt_values = dt_spec.astype(float).ravel().tolist()
    elif isinstance(dt_spec, (list, tuple)):
        dt_values = [float(v) for v in dt_spec]
    else:
        dt_values = [float(dt_spec)]

    if not dt_values:
        raise ValueError("dt list is empty")

    if len(dt_values) == 1:
        return dt_values * n_jobs

    if len(dt_values) != n_jobs:
        raise ValueError(
            f"dt has {len(dt_values)} entries, but the sweep creates {n_jobs} simulations. "
            "Use a scalar dt, a callable dt = lambda Da, Sd, gamy: ... or "
            "lambda Da, Sd, gamy, v: ..., "
            "or one dt value per generated simulation."
        )

    return dt_values


def call_dt_function(dt_spec, Da_value, Sd_value, gamy_value, v_value):
    """Call dt functions with either the old 3-arg or new 4-arg signature."""
    signature = inspect.signature(dt_spec)
    try:
        signature.bind(Da_value, Sd_value, gamy_value, v_value)
        use_v = True
    except TypeError:
        signature.bind(Da_value, Sd_value, gamy_value)
        use_v = False

    if use_v:
        return dt_spec(Da_value, Sd_value, gamy_value, v_value)

    return dt_spec(Da_value, Sd_value, gamy_value)


Da_values = as_float_list(Da, "Da")
Sd_values = as_float_list(Sd, "Sd")
gamy_values = as_float_list(gamy, "gamy")
v_values = as_float_list(v, "v")


def build_parameter_combinations():
    mode = str(sweep_mode).lower()

    if mode in {"product", "cartesian", "all"}:
        return list(itertools.product(Da_values, Sd_values, gamy_values, v_values))

    if mode in {"paired", "zip", "ordered"}:
        parameter_lists = {
            "Da": Da_values,
            "Sd": Sd_values,
            "gamy": gamy_values,
            "v": v_values,
        }
        non_scalar_lengths = sorted({len(values) for values in parameter_lists.values() if len(values) != 1})

        if len(non_scalar_lengths) > 1:
            lengths = ", ".join(f"{name} has length {len(values)}" for name, values in parameter_lists.items())
            raise ValueError(
                "paired sweep mode requires every non-scalar parameter list to have the same length; "
                + lengths
            )

        n_jobs = non_scalar_lengths[0] if non_scalar_lengths else 1

        def value_at(values, index):
            return values[0] if len(values) == 1 else values[index]

        return [
            (
                value_at(Da_values, i),
                value_at(Sd_values, i),
                value_at(gamy_values, i),
                value_at(v_values, i),
            )
            for i in range(n_jobs)
        ]

    raise ValueError('sweep_mode must be "product" or "paired"')


def lastFrame(directory):
    frames = []

    for file in os.listdir(directory):
        if file.startswith("geo") and file.endswith(".mat"):
            try:
                frame = int(file.split("geo")[1].split(".")[0])
                frames.append(frame)
            except Exception:
                pass

    return max(frames) if frames else 0


def make_run_tag(Da_value, Sd_value, gamy_value, v_value):
    return (
        f"Sd_{Sd_value:.2e}_Da_{Da_value:.2e}_gamy_{gamy_value:+.2e}_v_{v_value:.2e}"
        .replace("+", "p")
        .replace("-", "m")
    )


def make_matlab_command(Da_value, Sd_value, gamy_value, v_value, dt_value, dir_path, start):
    """
    Build a single-line MATLAB command for -r.

    This avoids:
      - shell=True
      - MATLAB -batch multiline parsing
      - generated .m driver files
    """

    pieces = [
        "try",
        f"cd({matlab_string(here)})",
        f"verbose = {verbose}",
        f"supress_outputs = {supress_outputs}",
        f"dir = {matlab_string(dir_path + '/')}",
        f"start = {start}",
        "p = struct()",
        f"p.roughness = {roughness}",
        f"p.dt = {dt_value:.17g}",
        f"p.T = {T}",
        f"p.start = {start}",
        f"p.subdivisions = {subdivisions}",
        f"p.k = {k}",
        f"p.remesh_size = {remesh_size}",
        f"p.precondition_system = {precond}",
        f"p.Da = {Da_value:.17g}",
        f"p.Sd = {Sd_value:.17g}",
        f"p.Gamma = {Gamma:.17g}",
        f"p.gamy = {gamy_value:.17g}",
        f"p.v = {v_value:.17g}",
        f"p.chi = {chi:.17g}",
        "fs_multi",
        "exit(0)",
        "catch ME",
        "disp(getReport(ME, 'extended'))",
        "exit(1)",
        "end",
    ]

    cmd = "; ".join(pieces)

    try:
        cmd.encode("ascii")
    except UnicodeEncodeError as e:
        raise RuntimeError(f"Non-ASCII character in MATLAB command: {e}") from e

    return cmd


@dataclass
class Job:
    run_tag: str
    Da: float
    Sd: float
    gamy: float
    v: float
    dt: float
    dir_path: str
    log_path: str
    matlab_command: str


@dataclass
class RunningJob:
    job: Job
    process: subprocess.Popen
    log_file: object
    reader_thread: threading.Thread


def build_jobs(parameter_combinations=None):
    jobs = []

    if parameter_combinations is None:
        parameter_combinations = build_parameter_combinations()

    dt_values = resolve_dt_values(dt, parameter_combinations)

    for (Da_value, Sd_value, gamy_value, v_value), dt_value in zip(parameter_combinations, dt_values):
        run_tag = make_run_tag(Da_value, Sd_value, gamy_value, v_value)
        dir_path = os.path.join(here, "data", "fs_batch_data", run_tag)
        os.makedirs(dir_path, exist_ok=True)

        start = lastFrame(dir_path) if resume else 0

        if resume:
            print(f"[{run_tag}] resume start frame: {start}")
        print(f"[{run_tag}] dt: {dt_value:.17g}")

        log_path = os.path.join(dir_path, "matlab.log")
        matlab_command = make_matlab_command(Da_value, Sd_value, gamy_value, v_value, dt_value, dir_path, start)

        jobs.append(
            Job(
                run_tag=run_tag,
                Da=Da_value,
                Sd=Sd_value,
                gamy=gamy_value,
                v=v_value,
                dt=dt_value,
                dir_path=dir_path,
                log_path=log_path,
                matlab_command=matlab_command,
            )
        )

    return jobs


# ============================================================
# Old-job cleanup
# ============================================================

def find_old_batch_process_groups():
    current_pgid = os.getpgrp()

    result = subprocess.run(
        ["ps", "-u", str(os.getuid()), "-o", "pid=,ppid=,pgid=,command="],
        text=True,
        stdout=subprocess.PIPE,
        stderr=subprocess.DEVNULL,
    )

    pgids = set()

    for line in result.stdout.splitlines():
        parts = line.strip().split(maxsplit=3)

        if len(parts) < 4:
            continue

        try:
            pid = int(parts[0])
            pgid = int(parts[2])
        except ValueError:
            continue

        cmd = parts[3]

        if pid == os.getpid():
            continue

        if pgid == current_pgid:
            continue

        cmd_lower = cmd.lower()

        is_old_inline_batch = "fs_multi" in cmd and here in cmd
        is_old_driver_batch = "_fs_batch_driver.m" in cmd and here in cmd
        is_batch_data_matlab = "matlab" in cmd_lower and "fs_batch_data" in cmd and here in cmd

        if is_old_inline_batch or is_old_driver_batch or is_batch_data_matlab:
            pgids.add(pgid)

    return pgids


def process_group_exists(pgid):
    try:
        os.killpg(pgid, 0)
        return True
    except ProcessLookupError:
        return False
    except PermissionError:
        return True


def kill_process_group(pgid, label="", grace_seconds=5.0):
    if not process_group_exists(pgid):
        return

    prefix = f"{label}: " if label else ""

    print(f"{prefix}killing process group {pgid} with SIGTERM", file=sys.stderr)

    try:
        os.killpg(pgid, signal.SIGTERM)
    except ProcessLookupError:
        return

    deadline = time.time() + grace_seconds

    while time.time() < deadline:
        if not process_group_exists(pgid):
            return
        time.sleep(0.25)

    if process_group_exists(pgid):
        print(f"{prefix}process group {pgid} survived; killing with SIGKILL", file=sys.stderr)

        try:
            os.killpg(pgid, signal.SIGKILL)
        except ProcessLookupError:
            pass


def clean_old_batch_jobs():
    pgids = find_old_batch_process_groups()

    if not pgids:
        print("No old MATLAB batch process groups found.")
        return

    print("Found old MATLAB batch process groups:")

    for pgid in sorted(pgids):
        print(f"  PGID {pgid}")

    for pgid in sorted(pgids):
        kill_process_group(pgid, label="old batch")


# ============================================================
# Launching and monitoring
# ============================================================

def stream_output(running):
    process = running.process
    job = running.job
    log_file = running.log_file

    assert process.stdout is not None

    for line in process.stdout:
        log_file.write(line)
        log_file.flush()

        if not is_noisy(line):
            sys.stdout.write(f"[{job.run_tag}] {line}")
            sys.stdout.flush()


def launch_job(job):
    env = os.environ.copy()
    env["LD_PRELOAD"] = LD_PRELOAD_PATH

    log_file = open(job.log_path, "a", buffering=1, encoding="utf-8")

    log_file.write("\n")
    log_file.write("=" * 80 + "\n")
    log_file.write(f"Starting job: {job.run_tag}\n")
    log_file.write(f"Da: {job.Da}\n")
    log_file.write(f"Sd: {job.Sd}\n")
    log_file.write(f"gamy: {job.gamy}\n")
    log_file.write(f"v: {job.v}\n")
    log_file.write(f"Directory: {job.dir_path}\n")
    log_file.write("MATLAB command:\n")
    log_file.write(job.matlab_command + "\n")
    log_file.write("=" * 80 + "\n")
    log_file.flush()

    process = subprocess.Popen(
        [
            "matlab",
            "-nodisplay",
            "-nosplash",
            "-nodesktop",
            "-r",
            job.matlab_command,
        ],
        cwd=here,
        env=env,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
        start_new_session=True,
    )

    running = RunningJob(
        job=job,
        process=process,
        log_file=log_file,
        reader_thread=None,
    )

    reader_thread = threading.Thread(target=stream_output, args=(running,), daemon=True)
    running.reader_thread = reader_thread
    reader_thread.start()

    print(f"Launched {job.run_tag} with MATLAB PID {process.pid}")

    return running


def stop_running_job(running):
    process = running.process

    if process.poll() is None:
        try:
            pgid = os.getpgid(process.pid)
        except ProcessLookupError:
            pgid = process.pid

        kill_process_group(pgid, label=running.job.run_tag)

    try:
        if process.stdout is not None:
            process.stdout.close()
    except Exception:
        pass

    try:
        running.reader_thread.join(timeout=2)
    except Exception:
        pass

    try:
        running.log_file.close()
    except Exception:
        pass


def close_finished_job(running):
    returncode = running.process.returncode

    try:
        running.reader_thread.join(timeout=2)
    except Exception:
        pass

    try:
        running.log_file.write(f"\nJob exited with code {returncode}\n")
        running.log_file.flush()
        running.log_file.close()
    except Exception:
        pass

    return returncode


def run_batch(jobs, max_workers):
    pending = list(jobs)
    running = []
    failures = 0

    try:
        while pending or running:
            while pending and len(running) < max_workers:
                job = pending.pop(0)
                running.append(launch_job(job))

            still_running = []

            for rjob in running:
                returncode = rjob.process.poll()

                if returncode is None:
                    still_running.append(rjob)
                    continue

                returncode = close_finished_job(rjob)

                if returncode == 0:
                    print(f"Finished {rjob.job.run_tag}")
                else:
                    failures += 1
                    print(
                        f"FAILED {rjob.job.run_tag} with exit code {returncode}. "
                        f"See log: {rjob.job.log_path}",
                        file=sys.stderr,
                    )

            running = still_running
            time.sleep(0.5)

    except KeyboardInterrupt:
        print("\nInterrupted. Killing active MATLAB jobs...", file=sys.stderr)

        for rjob in list(running):
            stop_running_job(rjob)

        print("Stopped active MATLAB jobs.", file=sys.stderr)
        raise SystemExit(130)

    if failures:
        raise SystemExit(failures)


# ============================================================
# Main
# ============================================================

def main():
    print(f"Project directory: {here}")
    print(f"max_workers: {max_workers}")
    print(f"resume: {resume}")
    print(f"Da values: {Da_values}")
    print(f"Sd values: {Sd_values}")
    print(f"gamy values: {gamy_values}")
    print(f"v values: {v_values}")
    print(f"sweep mode: {sweep_mode}")
    parameter_combinations = build_parameter_combinations()
    print(f"number of jobs: {len(parameter_combinations)}")

    if PRE_CLEAN_OLD_BATCH_JOBS:
        clean_old_batch_jobs()

    jobs = build_jobs(parameter_combinations)

    print("Jobs to run:")

    for job in jobs:
        print(f"  {job.run_tag}")

    run_batch(jobs, max_workers=max_workers)


if __name__ == "__main__":
    main()
# Out:
# Project directory: /home/nickbroussinos/Code/evolving_stokes_codex/remesh/
# max_workers: 1
# resume: True
# Da values: [0.0]
# Sd values: [0.01, 0.03, 0.1, 0.3, 1.0, 3.0, 10.0, 30.0, 100.0]
# gamy values: [0.0]
# v values: [0.97]
# sweep mode: product
# number of jobs: 9
# Found old MATLAB batch process groups:
#   PGID 36643
#   PGID 36647
#   PGID 36652
#   PGID 36657
#   PGID 36664
# old batch: killing process group 36643 with SIGTERM
# old batch: process group 36643 survived; killing with SIGKILL
# old batch: killing process group 36647 with SIGTERM
# old batch: process group 36647 survived; killing with SIGKILL
# old batch: killing process group 36652 with SIGTERM
# old batch: process group 36652 survived; killing with SIGKILL
# old batch: killing process group 36657 with SIGTERM
# old batch: process group 36657 survived; killing with SIGKILL
# old batch: killing process group 36664 with SIGTERM
# old batch: process group 36664 survived; killing with SIGKILL
# [Sd_1.00em02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] resume start frame: 4
# [Sd_1.00em02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] dt: 10
# [Sd_3.00em02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] resume start frame: 2
# [Sd_3.00em02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] dt: 3.3333333333333335
# [Sd_1.00em01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] resume start frame: 11
# [Sd_1.00em01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] dt: 1
# [Sd_3.00em01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] resume start frame: 3
# [Sd_3.00em01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] dt: 0.33333333333333337
# [Sd_1.00ep00_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] resume start frame: 8
# [Sd_1.00ep00_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] dt: 0.10000000000000001
# [Sd_3.00ep00_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] resume start frame: 2
# [Sd_3.00ep00_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] dt: 0.033333333333333333
# [Sd_1.00ep01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] resume start frame: 15
# [Sd_1.00ep01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] dt: 0.01
# [Sd_3.00ep01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] resume start frame: 3
# [Sd_3.00ep01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] dt: 0.0033333333333333331
# [Sd_1.00ep02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] resume start frame: 14
# [Sd_1.00ep02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01] dt: 0.001
# Jobs to run:
#   Sd_1.00em02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01
#   Sd_3.00em02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01
#   Sd_1.00em01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01
#   Sd_3.00em01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01
#   Sd_1.00ep00_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01
#   Sd_3.00ep00_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01
#   Sd_1.00ep01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01
#   Sd_3.00ep01_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01
#   Sd_1.00ep02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01
# Launched Sd_1.00em02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01 with MATLAB PID 37594
# Interrupted. Killing active MATLAB jobs...
# Sd_1.00em02_Da_0.00ep00_gamy_p0.00ep00_v_9.70em01: killing process group 37594 with SIGTERM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 583, in run_batch(jobs, max_workers)
#     582         running = still_running
# --> 583         time.sleep(0.5)
#     585 except KeyboardInterrupt:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 628
#     624     run_batch(jobs, max_workers=max_workers)
#     627 if __name__ == "__main__":
# --> 628     main()
#
# Cell In[2], line 624, in main()
#     621 for job in jobs:
#     622     print(f"  {job.run_tag}")
# --> 624 run_batch(jobs, max_workers=max_workers)
#
# Cell In[2], line 589, in run_batch(jobs, max_workers)
#     586 print("\nInterrupted. Killing active MATLAB jobs...", file=sys.stderr)
#     588 for rjob in list(running):
# --> 589     stop_running_job(rjob)
#     591 print("Stopped active MATLAB jobs.", file=sys.stderr)
#     592 raise SystemExit(130)
#
# Cell In[2], line 513, in stop_running_job(running)
#     510     except ProcessLookupError:
#     511         pgid = process.pid
# --> 513     kill_process_group(pgid, label=running.job.run_tag)
#     515 try:
#     516     if process.stdout is not None:
#
# Cell In[2], line 404, in kill_process_group(pgid, label, grace_seconds)
#     402     if not process_group_exists(pgid):
#     403         return
# --> 404     time.sleep(0.25)
#     406 if process_group_exists(pgid):
#     407     print(f"{prefix}process group {pgid} survived; killing with SIGKILL", file=sys.stderr)
#
# KeyboardInterrupt:
