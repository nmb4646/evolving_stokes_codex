# %%
import subprocess
import os
import concurrent.futures

import threading
import sys

def _filter_stderr(pipe):
    noisy_patterns = [
        "MathWorksServiceHost",
        "GLIBCXX_3.4.31",
        "GLIBCXX_3.4.32",
        "CXXABI_1.3.15",
        "libmwflnetwork.so",
        "libmwflcrypto.so",
        "libmwflcryptoutils.so",
        "libmwflcryptoopenssl.so",
        "libmwflurlmgrfactory.so",
    ]

    for line in pipe:
        if not any(p in line for p in noisy_patterns):
            sys.stderr.write(line)
            sys.stderr.flush()

def run(cmd):
    process = subprocess.Popen(
        cmd,
        shell=True,
        text=True,
        stdout=None,
        stderr=subprocess.PIPE
    )

    t = threading.Thread(target=_filter_stderr, args=(process.stderr,))
    t.daemon = True
    t.start()

    returncode = process.wait()
    t.join(timeout=1)

    if returncode != 0:
        print(f"Command exited with code {returncode}", file=sys.stderr)

def lastFrame(directory):
    frames = [int(file.split("geo")[1].split(".")[0]) for file in os.listdir(directory) if file.startswith("geo") and file.endswith(".mat")]
    return max(frames)

here = "/home/nickbroussinos/Code/evolving_stokes_codex/remesh/"

# Inputs
verbose = 'true'
resume = False
supress_outputs = 0
subdivisions = 13
roughness = .0005
remesh_size = 0
T = 40000
k = 10000
Da = 100
Sd = 20
Gamma = 0
gamy = 10
chi = 1e-4

param = [.01] # dt values

commands = []
for dt in param:
        run_tag = f"Sd_{Sd:.2e}_Da_{Da:.2e}_gamy_{gamy:+.2e}".replace('+', 'p').replace('-', 'm')
        dir_path = here + f"data/fs_batch_data/{run_tag}"
        os.makedirs(dir_path, exist_ok=True)
        start = (lastFrame(dir_path)) if resume else 0
        if resume:
            print(f"start: {start}")
        cmd = f"""export LD_PRELOAD=/usr/lib/x86_64-linux-gnu/libstdc++.so.6 && \
    matlab -nodisplay -nosplash -nodesktop -r "cd '{here}'; verbose = {verbose};\
    supress_outputs = {supress_outputs}; dir = '{dir_path}/'; start = {start};\
    p = struct(); p.roughness = {roughness}; p.dt={dt}; p.T={T}; p.start={start};\
    p.subdivisions={subdivisions}; p.k={k}; p.remesh_size = {remesh_size};\
    p.Da={Da}; p.Sd={Sd}; p.Gamma={Gamma}; p.gamy={gamy}; p.chi={chi}; fs_multi; exit" """
        commands.append(cmd)


max_workers = 6
with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(run, cmd) for cmd in commands]
    concurrent.futures.wait(futures)
# Out:
#                             < M A T L A B (R) >
#                   Copyright 1984-2024 The MathWorks, Inc.
#              R2024a Update 3 (24.1.0.2603908) 64-bit (glnxa64)
#                                 May 2, 2024
#
#
# To get started, type doc.
# For product information, visit www.mathworks.com.
#
# Save geo0.mat
# t = 1, j = 0, ls_iter = 1, E = 0.01277878813, eps_b = 38.19, eps_c = 50.82, eps_d = 0.0001849, darea = 0.002319
# t = 1, j = 1, ls_iter = 1, E = 0.0121914709, eps_b = 3.699, eps_c = 40.66, eps_d = 0.0001511, darea = 0.001895
# t = 1, j = 2, ls_iter = 1, E = 0.01229067098, eps_b = 3.083, eps_c = 32.53, eps_d = 0.0001253, darea = 0.001571
# t = 1, j = 3, ls_iter = 1, E = 0.01236314749, eps_b = 2.479, eps_c = 26.02, eps_d = 0.0001063, darea = 0.001334
# t = 1, j = 4, ls_iter = 1, E = 0.01241698851, eps_b = 1.983, eps_c = 20.82, eps_d = 9.228e-05, darea = 0.001158
# t = 1, j = 5, ls_iter = 1, E = 0.01245744638, eps_b = 1.586, eps_c = 16.66, eps_d = 8.178e-05, darea = 0.001026
# t = 1, j = 6, ls_iter = 1, E = 0.01248814435, eps_b = 1.269, eps_c = 13.32, eps_d = 7.384e-05, darea = 0.0009263
# t = 1, j = 7, ls_iter = 1, E = 0.01251163724, eps_b = 1.015, eps_c = 10.66, eps_d = 6.779e-05, darea = 0.0008503
# t = 1, j = 8, ls_iter = 1, E = 0.01252975138, eps_b = 0.8136, eps_c = 8.528, eps_d = 6.314e-05, darea = 0.000792
# t = 1, j = 9, ls_iter = 1, E = 0.01254380894, eps_b = 0.6526, eps_c = 6.822, eps_d = 5.954e-05, darea = 0.0007469
# t = 1, j = 10, ls_iter = 1, E = 0.01255477892, eps_b = 0.5244, eps_c = 5.458, eps_d = 5.675e-05, darea = 0.0007119
# t = 1, j = 11, ls_iter = 1, E = 0.01256337968, eps_b = 0.4226, eps_c = 4.367, eps_d = 5.458e-05, darea = 0.0006846
# t = 1, j = 12, ls_iter = 1, E = 0.01257014961, eps_b = 0.3419, eps_c = 3.493, eps_d = 5.288e-05, darea = 0.0006633
# t = 1, j = 13, ls_iter = 1, E = 0.01257549616, eps_b = 0.2784, eps_c = 2.795, eps_d = 5.155e-05, darea = 0.0006466
# t = 1, j = 14, ls_iter = 1, E = 0.01257973039, eps_b = 0.2289, eps_c = 2.236, eps_d = 5.051e-05, darea = 0.0006336
# t = 1, j = 15, ls_iter = 1, E = 0.01258309163, eps_b = 0.1908, eps_c = 1.789, eps_d = 4.971e-05, darea = 0.0006235
# t = 1, j = 16, ls_iter = 1, E = 0.01258576526, eps_b = 0.1619, eps_c = 1.431, eps_d = 4.908e-05, darea = 0.0006157
# t = 1, j = 17, ls_iter = 1, E = 0.01258789566, eps_b = 0.1407, eps_c = 1.145, eps_d = 4.861e-05, darea = 0.0006098
# t = 1, j = 18, ls_iter = 1, E = 0.01258959582, eps_b = 0.1255, eps_c = 0.9158, eps_d = 4.825e-05, darea = 0.0006053
# t = 1, j = 19, ls_iter = 1, E = 0.01259095455, eps_b = 0.1151, eps_c = 0.7327, eps_d = 4.8e-05, darea = 0.0006021
# t = 1, j = 20, ls_iter = 1, E = 0.01259204186, eps_b = 0.1082, eps_c = 0.5861, eps_d = 4.782e-05, darea = 0.0005998
# t = 1, j = 21, ls_iter = 1, E = 0.01259291311, eps_b = 0.104, eps_c = 0.4689, eps_d = 4.77e-05, darea = 0.0005984
# t = 1, j = 22, ls_iter = 1, E = 0.01259361215, eps_b = 0.1015, eps_c = 0.3751, eps_d = 4.764e-05, darea = 0.0005976
# t = 1, j = 23, ls_iter = 1, E = 0.01259417379, eps_b = 0.1002, eps_c = 0.3001, eps_d = 4.763e-05, darea = 0.0005974
# t = 1, j = 24, ls_iter = 1, E = 0.01259462572, eps_b = 0.09973, eps_c = 0.2401, eps_d = 4.765e-05, darea = 0.0005978
# t = 1, j = 25, ls_iter = 1, E = 0.01259498998, eps_b = 0.0997, eps_c = 0.1921, eps_d = 4.771e-05, darea = 0.0005985
# t = 1, j = 26, ls_iter = 1, E = 0.01259528413, eps_b = 0.09994, eps_c = 0.1537, eps_d = 4.78e-05, darea = 0.0005996
# t = 1, j = 27, ls_iter = 1, E = 0.01259552216, eps_b = 0.1003, eps_c = 0.1229, eps_d = 4.791e-05, darea = 0.000601
# t = 1, j = 28, ls_iter = 1, E = 0.01259571525, eps_b = 0.1008, eps_c = 0.09835, eps_d = 4.804e-05, darea = 0.0006026
# t = 1, j = 29, ls_iter = 1, E = 0.01259587232, eps_b = 0.1013, eps_c = 0.07869, eps_d = 4.819e-05, darea = 0.0006046
# t = 1, j = 30, ls_iter = 1, E = 0.0125960005, eps_b = 0.1017, eps_c = 0.06296, eps_d = 4.837e-05, darea = 0.0006067
# t = 1, j = 31, ls_iter = 1, E = 0.0125961055, eps_b = 0.1021, eps_c = 0.05038, eps_d = 4.855e-05, darea = 0.0006091
# t = 1, j = 32, ls_iter = 1, E = 0.01259619185, eps_b = 0.1025, eps_c = 0.04032, eps_d = 4.876e-05, darea = 0.0006116
# t = 1, j = 33, ls_iter = 1, E = 0.01259626322, eps_b = 0.1028, eps_c = 0.03227, eps_d = 4.897e-05, darea = 0.0006143
# t = 1, j = 34, ls_iter = 1, E = 0.0125963225, eps_b = 0.1031, eps_c = 0.02585, eps_d = 4.92e-05, darea = 0.0006172
# t = 1, j = 35, ls_iter = 1, E = 0.01259637204, eps_b = 0.1033, eps_c = 0.02071, eps_d = 4.944e-05, darea = 0.0006202
# t = 1, j = 36, ls_iter = 1, E = 0.0125964137, eps_b = 0.1034, eps_c = 0.01661, eps_d = 4.97e-05, darea = 0.0006234
# t = 1, j = 37, ls_iter = 1, E = 0.01259644898, eps_b = 0.1035, eps_c = 0.01335, eps_d = 4.996e-05, darea = 0.0006267
# t = 1, j = 38, ls_iter = 1, E = 0.01259647907, eps_b = 0.1035, eps_c = 0.01075, eps_d = 5.023e-05, darea = 0.0006301
# t = 1, j = 39, ls_iter = 1, E = 0.01259650493, eps_b = 0.1035, eps_c = 0.008691, eps_d = 5.051e-05, darea = 0.0006336
# t = 1, j = 40, ls_iter = 1, E = 0.01259652732, eps_b = 0.1035, eps_c = 0.007069, eps_d = 5.079e-05, darea = 0.0006372
# t = 1, j = 41, ls_iter = 1, E = 0.01259654687, eps_b = 0.1034, eps_c = 0.005802, eps_d = 5.109e-05, darea = 0.0006409
# t = 1, j = 42, ls_iter = 1, E = 0.01259656407, eps_b = 0.1034, eps_c = 0.004822, eps_d = 5.139e-05, darea = 0.0006446
# Save geo1.mat at j = 43, eps_b = 0.1034, eps_c = 0.004822, eps_d = 5.139e-05, total time: 28.2495
# t = 2, j = 0, ls_iter = 1, E = 0.01552061297, eps_b = 76.68, eps_c = 0.003667, eps_d = 5.582e-07, darea = 7.002e-06
# t = 2, j = 1, ls_iter = 1, E = 0.01258176554, eps_b = 0.3901, eps_c = 0.003093, eps_d = 6.301e-07, darea = 7.904e-06
# Save geo2.mat at j = 2, eps_b = 0.3901, eps_c = 0.003093, eps_d = 6.301e-07, total time: 30.8438
# t = 3, j = 0, ls_iter = 1, E = 0.01258166754, eps_b = 1.897, eps_c = 0.002607, eps_d = 9.29e-09, darea = -1.165e-07
# t = 3, j = 1, ls_iter = 1, E = 0.01257979745, eps_b = 0.2699, eps_c = 0.002331, eps_d = 1.059e-07, darea = 1.329e-06
# Save geo3.mat at j = 2, eps_b = 0.2699, eps_c = 0.002331, eps_d = 1.059e-07, total time: 33.3056
# t = 4, j = 0, ls_iter = 1, E = 0.01257928761, eps_b = 0.6305, eps_c = 0.002078, eps_d = 8.073e-08, darea = -1.013e-06
# Save geo4.mat at j = 1, eps_b = 0.6305, eps_c = 0.002078, eps_d = 8.073e-08, total time: 35.2729
# t = 5, j = 0, ls_iter = 1, E = 0.01257875741, eps_b = 0.4156, eps_c = 0.001933, eps_d = 1.009e-07, darea = -1.265e-06
# Save geo5.mat at j = 1, eps_b = 0.4156, eps_c = 0.001933, eps_d = 1.009e-07, total time: 37.2306
# t = 6, j = 0, ls_iter = 1, E = 0.01257845512, eps_b = 0.3394, eps_c = 0.001839, eps_d = 1.073e-07, darea = -1.346e-06
# Save geo6.mat at j = 1, eps_b = 0.3394, eps_c = 0.001839, eps_d = 1.073e-07, total time: 39.4109
# t = 7, j = 0, ls_iter = 1, E = 0.01257823552, eps_b = 0.3111, eps_c = 0.001779, eps_d = 1.089e-07, darea = -1.367e-06
# Save geo7.mat at j = 1, eps_b = 0.3111, eps_c = 0.001779, eps_d = 1.089e-07, total time: 41.5096
# t = 8, j = 0, ls_iter = 1, E = 0.01257805342, eps_b = 0.3036, eps_c = 0.001741, eps_d = 1.088e-07, darea = -1.364e-06
# Save geo8.mat at j = 1, eps_b = 0.3036, eps_c = 0.001741, eps_d = 1.088e-07, total time: 43.8334
# t = 9, j = 0, ls_iter = 1, E = 0.01257789125, eps_b = 0.3038, eps_c = 0.001719, eps_d = 1.078e-07, darea = -1.353e-06
# Save geo9.mat at j = 1, eps_b = 0.3038, eps_c = 0.001719, eps_d = 1.078e-07, total time: 45.8586
# t = 10, j = 0, ls_iter = 1, E = 0.0125777418, eps_b = 0.3067, eps_c = 0.001706, eps_d = 1.065e-07, darea = -1.336e-06
# Save geo10.mat at j = 1, eps_b = 0.3067, eps_c = 0.001706, eps_d = 1.065e-07, total time: 48.2431
# t = 11, j = 0, ls_iter = 1, E = 0.01257760177, eps_b = 0.3107, eps_c = 0.0017, eps_d = 1.05e-07, darea = -1.318e-06
# Save geo11.mat at j = 1, eps_b = 0.3107, eps_c = 0.0017, eps_d = 1.05e-07, total time: 50.1203
# t = 12, j = 0, ls_iter = 1, E = 0.01257746939, eps_b = 0.3151, eps_c = 0.001697, eps_d = 1.034e-07, darea = -1.297e-06
# Save geo12.mat at j = 1, eps_b = 0.3151, eps_c = 0.001697, eps_d = 1.034e-07, total time: 52.4611
# t = 13, j = 0, ls_iter = 1, E = 0.01257734361, eps_b = 0.3196, eps_c = 0.001698, eps_d = 1.017e-07, darea = -1.275e-06
# Save geo13.mat at j = 1, eps_b = 0.3196, eps_c = 0.001698, eps_d = 1.017e-07, total time: 54.2928
# t = 14, j = 0, ls_iter = 1, E = 0.01257722371, eps_b = 0.3243, eps_c = 0.0017, eps_d = 9.988e-08, darea = -1.253e-06
# Save geo14.mat at j = 1, eps_b = 0.3243, eps_c = 0.0017, eps_d = 9.988e-08, total time: 56.5104
# t = 15, j = 0, ls_iter = 1, E = 0.01257710916, eps_b = 0.3291, eps_c = 0.001703, eps_d = 9.803e-08, darea = -1.23e-06
# Save geo15.mat at j = 1, eps_b = 0.3291, eps_c = 0.001703, eps_d = 9.803e-08, total time: 58.4572
# t = 16, j = 0, ls_iter = 1, E = 0.01257699956, eps_b = 0.3339, eps_c = 0.001707, eps_d = 9.612e-08, darea = -1.206e-06
# Save geo16.mat at j = 1, eps_b = 0.3339, eps_c = 0.001707, eps_d = 9.612e-08, total time: 60.4090
# t = 17, j = 0, ls_iter = 1, E = 0.01257689458, eps_b = 0.3387, eps_c = 0.001711, eps_d = 9.417e-08, darea = -1.181e-06
# Save geo17.mat at j = 1, eps_b = 0.3387, eps_c = 0.001711, eps_d = 9.417e-08, total time: 62.2115
# t = 18, j = 0, ls_iter = 1, E = 0.01257679392, eps_b = 0.3435, eps_c = 0.001715, eps_d = 9.218e-08, darea = -1.156e-06
# Save geo18.mat at j = 1, eps_b = 0.3435, eps_c = 0.001715, eps_d = 9.218e-08, total time: 64.0409
# t = 19, j = 0, ls_iter = 1, E = 0.01257669735, eps_b = 0.3484, eps_c = 0.00172, eps_d = 9.015e-08, darea = -1.131e-06
# Save geo19.mat at j = 1, eps_b = 0.3484, eps_c = 0.00172, eps_d = 9.015e-08, total time: 66.2092
# t = 20, j = 0, ls_iter = 1, E = 0.01257660464, eps_b = 0.3533, eps_c = 0.001724, eps_d = 8.808e-08, darea = -1.105e-06
# Save geo20.mat at j = 1, eps_b = 0.3533, eps_c = 0.001724, eps_d = 8.808e-08, total time: 68.1753
# t = 21, j = 0, ls_iter = 1, E = 0.0125765156, eps_b = 0.3583, eps_c = 0.001729, eps_d = 8.597e-08, darea = -1.078e-06
# Save geo21.mat at j = 1, eps_b = 0.3583, eps_c = 0.001729, eps_d = 8.597e-08, total time: 70.6179
# t = 22, j = 0, ls_iter = 1, E = 0.01257643006, eps_b = 0.3632, eps_c = 0.001734, eps_d = 8.383e-08, darea = -1.052e-06
# Save geo22.mat at j = 1, eps_b = 0.3632, eps_c = 0.001734, eps_d = 8.383e-08, total time: 72.4805
# t = 23, j = 0, ls_iter = 1, E = 0.01257634785, eps_b = 0.3682, eps_c = 0.001739, eps_d = 8.165e-08, darea = -1.024e-06
# Save geo23.mat at j = 1, eps_b = 0.3682, eps_c = 0.001739, eps_d = 8.165e-08, total time: 74.7810
# t = 24, j = 0, ls_iter = 1, E = 0.01257626881, eps_b = 0.3732, eps_c = 0.001744, eps_d = 7.944e-08, darea = -9.965e-07
# Save geo24.mat at j = 1, eps_b = 0.3732, eps_c = 0.001744, eps_d = 7.944e-08, total time: 76.5600
# t = 25, j = 0, ls_iter = 1, E = 0.01257619281, eps_b = 0.3782, eps_c = 0.001749, eps_d = 7.719e-08, darea = -9.683e-07
# Save geo25.mat at j = 1, eps_b = 0.3782, eps_c = 0.001749, eps_d = 7.719e-08, total time: 78.9283
# t = 26, j = 0, ls_iter = 1, E = 0.01257611971, eps_b = 0.3833, eps_c = 0.001753, eps_d = 7.491e-08, darea = -9.396e-07
# Save geo26.mat at j = 1, eps_b = 0.3833, eps_c = 0.001753, eps_d = 7.491e-08, total time: 80.4845
# t = 27, j = 0, ls_iter = 1, E = 0.01257604939, eps_b = 0.3883, eps_c = 0.001758, eps_d = 7.259e-08, darea = -9.105e-07
# Save geo27.mat at j = 1, eps_b = 0.3883, eps_c = 0.001758, eps_d = 7.259e-08, total time: 82.4324
# t = 28, j = 0, ls_iter = 1, E = 0.01257598174, eps_b = 0.3934, eps_c = 0.001763, eps_d = 7.023e-08, darea = -8.81e-07
# Save geo28.mat at j = 1, eps_b = 0.3934, eps_c = 0.001763, eps_d = 7.023e-08, total time: 84.0509
# t = 29, j = 0, ls_iter = 1, E = 0.01257591665, eps_b = 0.3985, eps_c = 0.001769, eps_d = 6.785e-08, darea = -8.511e-07
# Save geo29.mat at j = 1, eps_b = 0.3985, eps_c = 0.001769, eps_d = 6.785e-08, total time: 86.1130
# t = 30, j = 0, ls_iter = 1, E = 0.012575854, eps_b = 0.4037, eps_c = 0.001774, eps_d = 6.542e-08, darea = -8.207e-07
# Save geo30.mat at j = 1, eps_b = 0.4037, eps_c = 0.001774, eps_d = 6.542e-08, total time: 87.9749
# t = 31, j = 0, ls_iter = 1, E = 0.0125757937, eps_b = 0.4088, eps_c = 0.001779, eps_d = 6.297e-08, darea = -7.899e-07
# Save geo31.mat at j = 1, eps_b = 0.4088, eps_c = 0.001779, eps_d = 6.297e-08, total time: 90.1059
# t = 32, j = 0, ls_iter = 1, E = 0.01257573566, eps_b = 0.414, eps_c = 0.001784, eps_d = 6.048e-08, darea = -7.586e-07
# Save geo32.mat at j = 1, eps_b = 0.414, eps_c = 0.001784, eps_d = 6.048e-08, total time: 91.9926
# t = 33, j = 0, ls_iter = 1, E = 0.01257567979, eps_b = 0.4192, eps_c = 0.001789, eps_d = 5.795e-08, darea = -7.27e-07
# Save geo33.mat at j = 1, eps_b = 0.4192, eps_c = 0.001789, eps_d = 5.795e-08, total time: 94.1039
# t = 34, j = 0, ls_iter = 1, E = 0.01257562599, eps_b = 0.4244, eps_c = 0.001794, eps_d = 5.539e-08, darea = -6.948e-07
# Save geo34.mat at j = 1, eps_b = 0.4244, eps_c = 0.001794, eps_d = 5.539e-08, total time: 96.1581
# t = 35, j = 0, ls_iter = 1, E = 0.0125755742, eps_b = 0.4296, eps_c = 0.0018, eps_d = 5.28e-08, darea = -6.623e-07
# Save geo35.mat at j = 1, eps_b = 0.4296, eps_c = 0.0018, eps_d = 5.28e-08, total time: 97.9775
# t = 36, j = 0, ls_iter = 1, E = 0.01257552433, eps_b = 0.4349, eps_c = 0.001805, eps_d = 5.017e-08, darea = -6.293e-07
# Save geo36.mat at j = 1, eps_b = 0.4349, eps_c = 0.001805, eps_d = 5.017e-08, total time: 100.2877
# t = 37, j = 0, ls_iter = 1, E = 0.01257547631, eps_b = 0.4402, eps_c = 0.00181, eps_d = 4.75e-08, darea = -5.959e-07
# Save geo37.mat at j = 1, eps_b = 0.4402, eps_c = 0.00181, eps_d = 4.75e-08, total time: 102.1456
# t = 38, j = 0, ls_iter = 1, E = 0.01257543006, eps_b = 0.4455, eps_c = 0.001816, eps_d = 4.48e-08, darea = -5.62e-07
# Save geo38.mat at j = 1, eps_b = 0.4455, eps_c = 0.001816, eps_d = 4.48e-08, total time: 104.5280
# t = 39, j = 0, ls_iter = 1, E = 0.01257538553, eps_b = 0.4508, eps_c = 0.001821, eps_d = 4.207e-08, darea = -5.277e-07
# Save geo39.mat at j = 1, eps_b = 0.4508, eps_c = 0.001821, eps_d = 4.207e-08, total time: 106.0556
# t = 40, j = 0, ls_iter = 1, E = 0.01257534263, eps_b = 0.4561, eps_c = 0.001826, eps_d = 3.93e-08, darea = -4.93e-07
# Save geo40.mat at j = 1, eps_b = 0.4561, eps_c = 0.001826, eps_d = 3.93e-08, total time: 108.3058
# t = 41, j = 0, ls_iter = 1, E = 0.01257530133, eps_b = 0.4615, eps_c = 0.001832, eps_d = 3.649e-08, darea = -4.578e-07
# Save geo41.mat at j = 1, eps_b = 0.4615, eps_c = 0.001832, eps_d = 3.649e-08, total time: 110.1592
# t = 42, j = 0, ls_iter = 1, E = 0.01257526154, eps_b = 0.4669, eps_c = 0.001837, eps_d = 3.365e-08, darea = -4.221e-07
# Save geo42.mat at j = 1, eps_b = 0.4669, eps_c = 0.001837, eps_d = 3.365e-08, total time: 112.2801
# t = 43, j = 0, ls_iter = 1, E = 0.01257522322, eps_b = 0.4723, eps_c = 0.001843, eps_d = 3.077e-08, darea = -3.86e-07
# Save geo43.mat at j = 1, eps_b = 0.4723, eps_c = 0.001843, eps_d = 3.077e-08, total time: 114.3967
# t = 44, j = 0, ls_iter = 1, E = 0.01257518632, eps_b = 0.4778, eps_c = 0.001849, eps_d = 2.786e-08, darea = -3.495e-07
# Save geo44.mat at j = 1, eps_b = 0.4778, eps_c = 0.001849, eps_d = 2.786e-08, total time: 116.3305
# t = 45, j = 0, ls_iter = 1, E = 0.01257515077, eps_b = 0.4832, eps_c = 0.001854, eps_d = 2.491e-08, darea = -3.125e-07
# Save geo45.mat at j = 1, eps_b = 0.4832, eps_c = 0.001854, eps_d = 2.491e-08, total time: 118.4758
# t = 46, j = 0, ls_iter = 1, E = 0.01257511654, eps_b = 0.4887, eps_c = 0.00186, eps_d = 2.193e-08, darea = -2.751e-07
# Save geo46.mat at j = 1, eps_b = 0.4887, eps_c = 0.00186, eps_d = 2.193e-08, total time: 120.3237
# t = 47, j = 0, ls_iter = 1, E = 0.01257508357, eps_b = 0.4942, eps_c = 0.001866, eps_d = 1.891e-08, darea = -2.372e-07
# Save geo47.mat at j = 1, eps_b = 0.4942, eps_c = 0.001866, eps_d = 1.891e-08, total time: 122.5947
# t = 48, j = 0, ls_iter = 1, E = 0.01257505181, eps_b = 0.4997, eps_c = 0.001871, eps_d = 1.585e-08, darea = -1.989e-07
# Save geo48.mat at j = 1, eps_b = 0.4997, eps_c = 0.001871, eps_d = 1.585e-08, total time: 124.1125
# t = 49, j = 0, ls_iter = 1, E = 0.01257502122, eps_b = 0.5053, eps_c = 0.001877, eps_d = 1.276e-08, darea = -1.601e-07
# Save geo49.mat at j = 1, eps_b = 0.5053, eps_c = 0.001877, eps_d = 1.276e-08, total time: 126.4716
# t = 50, j = 0, ls_iter = 1, E = 0.01257499177, eps_b = 0.5109, eps_c = 0.001883, eps_d = 9.629e-09, darea = -1.208e-07
# Save geo50.mat at j = 1, eps_b = 0.5109, eps_c = 0.001883, eps_d = 9.629e-09, total time: 128.3332
# t = 51, j = 0, ls_iter = 1, E = 0.0125749634, eps_b = 0.5165, eps_c = 0.001889, eps_d = 6.463e-09, darea = -8.107e-08
# Save geo51.mat at j = 1, eps_b = 0.5165, eps_c = 0.001889, eps_d = 6.463e-09, total time: 130.6092
# t = 52, j = 0, ls_iter = 1, E = 0.01257493609, eps_b = 0.5221, eps_c = 0.001895, eps_d = 3.26e-09, darea = -4.089e-08
# Save geo52.mat at j = 1, eps_b = 0.5221, eps_c = 0.001895, eps_d = 3.26e-09, total time: 132.6256
# t = 53, j = 0, ls_iter = 1, E = 0.01257490978, eps_b = 0.5278, eps_c = 0.001901, eps_d = 1.923e-11, darea = -2.412e-10
# Save geo53.mat at j = 1, eps_b = 0.5278, eps_c = 0.001901, eps_d = 1.923e-11, total time: 134.6849
# t = 54, j = 0, ls_iter = 1, E = 0.01257488446, eps_b = 0.5334, eps_c = 0.001907, eps_d = 3.258e-09, darea = 4.087e-08
# Save geo54.mat at j = 1, eps_b = 0.5334, eps_c = 0.001907, eps_d = 3.258e-09, total time: 137.0404
# t = 55, j = 0, ls_iter = 1, E = 0.01257486008, eps_b = 0.5391, eps_c = 0.001913, eps_d = 6.573e-09, darea = 8.245e-08
# Save geo55.mat at j = 1, eps_b = 0.5391, eps_c = 0.001913, eps_d = 6.573e-09, total time: 139.1510
# t = 56, j = 0, ls_iter = 1, E = 0.0125748366, eps_b = 0.5449, eps_c = 0.001919, eps_d = 9.925e-09, darea = 1.245e-07
# Save geo56.mat at j = 1, eps_b = 0.5449, eps_c = 0.001919, eps_d = 9.925e-09, total time: 141.4178
# t = 57, j = 0, ls_iter = 1, E = 0.01257481401, eps_b = 0.5506, eps_c = 0.001925, eps_d = 1.331e-08, darea = 1.67e-07
# Save geo57.mat at j = 1, eps_b = 0.5506, eps_c = 0.001925, eps_d = 1.331e-08, total time: 143.1663
# t = 58, j = 0, ls_iter = 1, E = 0.01257479226, eps_b = 0.5564, eps_c = 0.001931, eps_d = 1.674e-08, darea = 2.1e-07
# Save geo58.mat at j = 1, eps_b = 0.5564, eps_c = 0.001931, eps_d = 1.674e-08, total time: 145.4878
# t = 59, j = 0, ls_iter = 1, E = 0.01257477133, eps_b = 0.5622, eps_c = 0.001937, eps_d = 2.021e-08, darea = 2.535e-07
# Save geo59.mat at j = 1, eps_b = 0.5622, eps_c = 0.001937, eps_d = 2.021e-08, total time: 147.4817
# t = 60, j = 0, ls_iter = 1, E = 0.01257475119, eps_b = 0.568, eps_c = 0.001943, eps_d = 2.371e-08, darea = 2.974e-07
# Save geo60.mat at j = 1, eps_b = 0.568, eps_c = 0.001943, eps_d = 2.371e-08, total time: 149.4144
# t = 61, j = 0, ls_iter = 1, E = 0.01257473182, eps_b = 0.5739, eps_c = 0.00195, eps_d = 2.725e-08, darea = 3.419e-07
# Save geo61.mat at j = 1, eps_b = 0.5739, eps_c = 0.00195, eps_d = 2.725e-08, total time: 151.1022
# t = 62, j = 0, ls_iter = 1, E = 0.01257471318, eps_b = 0.5798, eps_c = 0.001956, eps_d = 3.083e-08, darea = 3.868e-07
# Save geo62.mat at j = 1, eps_b = 0.5798, eps_c = 0.001956, eps_d = 3.083e-08, total time: 153.1360
# t = 63, j = 0, ls_iter = 1, E = 0.01257469525, eps_b = 0.5857, eps_c = 0.001962, eps_d = 3.445e-08, darea = 4.321e-07
# Save geo63.mat at j = 1, eps_b = 0.5857, eps_c = 0.001962, eps_d = 3.445e-08, total time: 154.7974
# t = 64, j = 0, ls_iter = 1, E = 0.01257467801, eps_b = 0.5916, eps_c = 0.001968, eps_d = 3.811e-08, darea = 4.78e-07
# Save geo64.mat at j = 1, eps_b = 0.5916, eps_c = 0.001968, eps_d = 3.811e-08, total time: 156.8184
# t = 65, j = 0, ls_iter = 1, E = 0.01257466144, eps_b = 0.5976, eps_c = 0.001975, eps_d = 4.18e-08, darea = 5.244e-07
# Save geo65.mat at j = 1, eps_b = 0.5976, eps_c = 0.001975, eps_d = 4.18e-08, total time: 158.9272
# t = 66, j = 0, ls_iter = 1, E = 0.01257464552, eps_b = 0.6035, eps_c = 0.001981, eps_d = 4.554e-08, darea = 5.712e-07
# Save geo66.mat at j = 1, eps_b = 0.6035, eps_c = 0.001981, eps_d = 4.554e-08, total time: 160.9187
# t = 67, j = 0, ls_iter = 1, E = 0.01257463021, eps_b = 0.6096, eps_c = 0.001988, eps_d = 4.931e-08, darea = 6.185e-07
# Save geo67.mat at j = 1, eps_b = 0.6096, eps_c = 0.001988, eps_d = 4.931e-08, total time: 163.3908
# t = 68, j = 0, ls_iter = 1, E = 0.01257461551, eps_b = 0.6156, eps_c = 0.001994, eps_d = 5.312e-08, darea = 6.664e-07
# Save geo68.mat at j = 1, eps_b = 0.6156, eps_c = 0.001994, eps_d = 5.312e-08, total time: 165.3288
# t = 69, j = 0, ls_iter = 1, E = 0.01257460139, eps_b = 0.6217, eps_c = 0.002001, eps_d = 5.697e-08, darea = 7.147e-07
# Save geo69.mat at j = 1, eps_b = 0.6217, eps_c = 0.002001, eps_d = 5.697e-08, total time: 167.7698
# t = 70, j = 0, ls_iter = 1, E = 0.01257458784, eps_b = 0.6278, eps_c = 0.002007, eps_d = 6.086e-08, darea = 7.635e-07
# Save geo70.mat at j = 1, eps_b = 0.6278, eps_c = 0.002007, eps_d = 6.086e-08, total time: 169.7353
# t = 71, j = 0, ls_iter = 1, E = 0.01257457483, eps_b = 0.6339, eps_c = 0.002014, eps_d = 6.48e-08, darea = 8.128e-07
# Save geo71.mat at j = 1, eps_b = 0.6339, eps_c = 0.002014, eps_d = 6.48e-08, total time: 172.1794
# t = 72, j = 0, ls_iter = 1, E = 0.01257456235, eps_b = 0.64, eps_c = 0.00202, eps_d = 6.877e-08, darea = 8.626e-07
# Save geo72.mat at j = 1, eps_b = 0.64, eps_c = 0.00202, eps_d = 6.877e-08, total time: 173.8983
# t = 73, j = 0, ls_iter = 1, E = 0.01257455038, eps_b = 0.6462, eps_c = 0.002027, eps_d = 7.278e-08, darea = 9.129e-07
# Save geo73.mat at j = 1, eps_b = 0.6462, eps_c = 0.002027, eps_d = 7.278e-08, total time: 175.7681
# t = 74, j = 0, ls_iter = 1, E = 0.01257453891, eps_b = 0.6524, eps_c = 0.002034, eps_d = 7.683e-08, darea = 9.637e-07
# Save geo74.mat at j = 1, eps_b = 0.6524, eps_c = 0.002034, eps_d = 7.683e-08, total time: 177.4954
# t = 75, j = 0, ls_iter = 1, E = 0.01257452792, eps_b = 0.6587, eps_c = 0.002041, eps_d = 8.092e-08, darea = 1.015e-06
# Save geo75.mat at j = 1, eps_b = 0.6587, eps_c = 0.002041, eps_d = 8.092e-08, total time: 179.4515
# t = 76, j = 0, ls_iter = 1, E = 0.0125745174, eps_b = 0.6649, eps_c = 0.002047, eps_d = 8.505e-08, darea = 1.067e-06
# Save geo76.mat at j = 1, eps_b = 0.6649, eps_c = 0.002047, eps_d = 8.505e-08, total time: 181.4034
# t = 77, j = 0, ls_iter = 1, E = 0.01257450733, eps_b = 0.6712, eps_c = 0.002054, eps_d = 8.922e-08, darea = 1.119e-06
# Save geo77.mat at j = 1, eps_b = 0.6712, eps_c = 0.002054, eps_d = 8.922e-08, total time: 183.2531
# t = 78, j = 0, ls_iter = 1, E = 0.0125744977, eps_b = 0.6776, eps_c = 0.002061, eps_d = 9.343e-08, darea = 1.172e-06
# Save geo78.mat at j = 1, eps_b = 0.6776, eps_c = 0.002061, eps_d = 9.343e-08, total time: 185.3240
# t = 79, j = 0, ls_iter = 1, E = 0.0125744885, eps_b = 0.6839, eps_c = 0.002068, eps_d = 9.769e-08, darea = 1.225e-06
# Save geo79.mat at j = 1, eps_b = 0.6839, eps_c = 0.002068, eps_d = 9.769e-08, total time: 187.1799
# t = 80, j = 0, ls_iter = 1, E = 0.01257447971, eps_b = 0.6903, eps_c = 0.002075, eps_d = 1.02e-07, darea = 1.279e-06
# Save geo80.mat at j = 1, eps_b = 0.6903, eps_c = 0.002075, eps_d = 1.02e-07, total time: 189.4593
# t = 81, j = 0, ls_iter = 1, E = 0.01257447132, eps_b = 0.6967, eps_c = 0.002082, eps_d = 1.063e-07, darea = 1.334e-06
# Save geo81.mat at j = 1, eps_b = 0.6967, eps_c = 0.002082, eps_d = 1.063e-07, total time: 191.3370
# t = 82, j = 0, ls_iter = 1, E = 0.01257446332, eps_b = 0.7032, eps_c = 0.002089, eps_d = 1.107e-07, darea = 1.389e-06
# Save geo82.mat at j = 1, eps_b = 0.7032, eps_c = 0.002089, eps_d = 1.107e-07, total time: 193.6344
# t = 83, j = 0, ls_iter = 1, E = 0.0125744557, eps_b = 0.7096, eps_c = 0.002096, eps_d = 1.151e-07, darea = 1.444e-06
# Save geo83.mat at j = 1, eps_b = 0.7096, eps_c = 0.002096, eps_d = 1.151e-07, total time: 195.5388
# t = 84, j = 0, ls_iter = 1, E = 0.01257444845, eps_b = 0.7162, eps_c = 0.002103, eps_d = 1.196e-07, darea = 1.5e-06
# Save geo84.mat at j = 1, eps_b = 0.7162, eps_c = 0.002103, eps_d = 1.196e-07, total time: 197.9760
# t = 85, j = 0, ls_iter = 1, E = 0.01257444156, eps_b = 0.7227, eps_c = 0.00211, eps_d = 1.241e-07, darea = 1.556e-06
# Save geo85.mat at j = 1, eps_b = 0.7227, eps_c = 0.00211, eps_d = 1.241e-07, total time: 199.8280
# t = 86, j = 0, ls_iter = 1, E = 0.01257443501, eps_b = 0.7293, eps_c = 0.002117, eps_d = 1.286e-07, darea = 1.613e-06
# Save geo86.mat at j = 1, eps_b = 0.7293, eps_c = 0.002117, eps_d = 1.286e-07, total time: 202.0037
# t = 87, j = 0, ls_iter = 1, E = 0.01257442881, eps_b = 0.7359, eps_c = 0.002124, eps_d = 1.332e-07, darea = 1.671e-06
# Save geo87.mat at j = 1, eps_b = 0.7359, eps_c = 0.002124, eps_d = 1.332e-07, total time: 204.1270
# t = 88, j = 0, ls_iter = 1, E = 0.01257442293, eps_b = 0.7425, eps_c = 0.002131, eps_d = 1.378e-07, darea = 1.729e-06
# Save geo88.mat at j = 1, eps_b = 0.7425, eps_c = 0.002131, eps_d = 1.378e-07, total time: 206.1546
# t = 89, j = 0, ls_iter = 1, E = 0.01257441738, eps_b = 0.7492, eps_c = 0.002139, eps_d = 1.425e-07, darea = 1.788e-06
# Save geo89.mat at j = 1, eps_b = 0.7492, eps_c = 0.002139, eps_d = 1.425e-07, total time: 207.9798
# t = 90, j = 0, ls_iter = 1, E = 0.01257441214, eps_b = 0.7558, eps_c = 0.002146, eps_d = 1.472e-07, darea = 1.847e-06
# Save geo90.mat at j = 1, eps_b = 0.7558, eps_c = 0.002146, eps_d = 1.472e-07, total time: 210.0244
# t = 91, j = 0, ls_iter = 1, E = 0.01257440721, eps_b = 0.7626, eps_c = 0.002153, eps_d = 1.52e-07, darea = 1.906e-06
# Save geo91.mat at j = 1, eps_b = 0.7626, eps_c = 0.002153, eps_d = 1.52e-07, total time: 212.4589
# t = 92, j = 0, ls_iter = 1, E = 0.01257440258, eps_b = 0.7693, eps_c = 0.00216, eps_d = 1.568e-07, darea = 1.967e-06
# Save geo92.mat at j = 1, eps_b = 0.7693, eps_c = 0.00216, eps_d = 1.568e-07, total time: 214.2754
# t = 93, j = 0, ls_iter = 1, E = 0.01257439824, eps_b = 0.7761, eps_c = 0.002168, eps_d = 1.616e-07, darea = 2.027e-06
# Save geo93.mat at j = 1, eps_b = 0.7761, eps_c = 0.002168, eps_d = 1.616e-07, total time: 216.7739
# t = 94, j = 0, ls_iter = 1, E = 0.01257439418, eps_b = 0.7829, eps_c = 0.002175, eps_d = 1.665e-07, darea = 2.089e-06
# Save geo94.mat at j = 1, eps_b = 0.7829, eps_c = 0.002175, eps_d = 1.665e-07, total time: 218.8030
# t = 95, j = 0, ls_iter = 1, E = 0.0125743904, eps_b = 0.7898, eps_c = 0.002183, eps_d = 1.714e-07, darea = 2.15e-06
# Save geo95.mat at j = 1, eps_b = 0.7898, eps_c = 0.002183, eps_d = 1.714e-07, total time: 221.3353
# t = 96, j = 0, ls_iter = 1, E = 0.01257438689, eps_b = 0.7967, eps_c = 0.00219, eps_d = 1.764e-07, darea = 2.213e-06
# Save geo96.mat at j = 1, eps_b = 0.7967, eps_c = 0.00219, eps_d = 1.764e-07, total time: 223.4644
# t = 97, j = 0, ls_iter = 1, E = 0.01257438364, eps_b = 0.8036, eps_c = 0.002198, eps_d = 1.814e-07, darea = 2.276e-06
# Save geo97.mat at j = 1, eps_b = 0.8036, eps_c = 0.002198, eps_d = 1.814e-07, total time: 225.3592
# t = 98, j = 0, ls_iter = 1, E = 0.01257438066, eps_b = 0.8106, eps_c = 0.002205, eps_d = 1.865e-07, darea = 2.339e-06
# Save geo98.mat at j = 1, eps_b = 0.8106, eps_c = 0.002205, eps_d = 1.865e-07, total time: 227.1024
# t = 99, j = 0, ls_iter = 1, E = 0.01257437793, eps_b = 0.8176, eps_c = 0.002213, eps_d = 1.916e-07, darea = 2.403e-06
# Save geo99.mat at j = 1, eps_b = 0.8176, eps_c = 0.002213, eps_d = 1.916e-07, total time: 229.0016
# t = 100, j = 0, ls_iter = 1, E = 0.01257437545, eps_b = 0.8246, eps_c = 0.00222, eps_d = 1.967e-07, darea = 2.468e-06
# Save geo100.mat at j = 1, eps_b = 0.8246, eps_c = 0.00222, eps_d = 1.967e-07, total time: 231.0291
# t = 101, j = 0, ls_iter = 1, E = 0.01257437321, eps_b = 0.8317, eps_c = 0.002228, eps_d = 2.019e-07, darea = 2.533e-06
# Save geo101.mat at j = 1, eps_b = 0.8317, eps_c = 0.002228, eps_d = 2.019e-07, total time: 232.8732
# Operation terminated by user during sptensor (line 347)
#
#
# In sptensor/ttt (line 160)
# c = sptensor(newsubs,newvals,[a.size(aremdims) b.size(bremdims)]);
#
# In Geometry/evolving_operators (line 327)
#             grad_ = squeeze(ttt(ttt(obj.grad, sptensor(ones(3, 1))), sptensor(ones(3,1))));
#
# In fs_multi (line 218)
#     [~, ~, ~, ~, KTK, DTD] = geo.evolving_operators();
#
# Operation terminated by user during sptensor (line 347)
#
#
# In sptensor/ttt (line 160)
# c = sptensor(newsubs,newvals,[a.size(aremdims) b.size(bremdims)]);
#
# In Geometry/evolving_operators (line 327)
#             grad_ = squeeze(ttt(ttt(obj.grad, sptensor(ones(3, 1))), sptensor(ones(3,1))));
#
# In fs_multi (line 218)
#     [~, ~, ~, ~, KTK, DTD] = geo.evolving_operators();
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 88
#      87 futures = [executor.submit(run, cmd) for cmd in commands]
# ---> 88 concurrent.futures.wait(futures)
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:307, in wait(fs, timeout, return_when)
#     305     waiter = _create_and_install_waiters(fs, return_when)
# --> 307 waiter.event.wait(timeout)
#     308 for f in fs:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 86
#      82         commands.append(cmd)
#      85 max_workers = 6
# ---> 86 with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
#      87     futures = [executor.submit(run, cmd) for cmd in commands]
#      88     concurrent.futures.wait(futures)
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
